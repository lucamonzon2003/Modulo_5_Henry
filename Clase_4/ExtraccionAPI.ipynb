# %% [markdown]
# ## Ejemplo 1: API del Banco Mundial (World Bank)
#
# La API de indicadores del Banco Mundial provee acceso programático a cerca de 16,000 series de tiempo de indicadores disponibles en plataformas online como Databank (https://databank.worldbank.org/). Muchas series de tiempo llegan hasta más de 50 años atrás, y pueden ser usadas para crear aplicaciones y análisis interesantes.
#
# La información general de la API del Banco Mundial está diponible en este link:
#
# https://datahelpdesk.worldbank.org/knowledgebase/articles/889392-about-the-indicators-api-documentation
#
# Y en particular, las isntrucciones para consultar la API están acá:
#
# https://datahelpdesk.worldbank.org/knowledgebase/articles/898581

# %% [markdown]
# Primero veamos como extrar el listado de todos los datos de la API Country, en formato JSON.

# %%
import requests
import pandas as pd

url='http://api.worldbank.org/v2/country'

# %%
# Primero veamos el caso de una query general, sin definir parámetros.
response=requests.get(url)
response.content
# Out:
# b'\xef\xbb\xbf<?xml version="1.0" encoding="utf-8"?>\r\n<wb:countries page="1" pages="6" per_page="50" total="297" xmlns:wb="http://www.worldbank.org">\r\n  <wb:country id="ABW">\r\n    <wb:iso2Code>AW</wb:iso2Code>\r\n    <wb:name>Aruba</wb:name>\r\n    <wb:region id="LCN" iso2code="ZJ">Latin America &amp; Caribbean </wb:region>\r\n    <wb:adminregion id="" iso2code="" />\r\n    <wb:incomeLevel id="HIC" iso2code="XD">High income</wb:incomeLevel>\r\n    <wb:lendingType id="LNX" iso2code="XX">Not classified</wb:lendingType>\r\n    <wb:capitalCity>Oranjestad</wb:capitalCity>\r\n    <wb:longitude>-70.0167</wb:longitude>\r\n    <wb:latitude>12.5167</wb:latitude>\r\n  </wb:country>\r\n  <wb:country id="AFE">\r\n    <wb:iso2Code>ZH</wb:iso2Code>\r\n    <wb:name>Africa Eastern and Southern</wb:name>\r\n    <wb:region id="NA" iso2code="NA">Aggregates</wb:region>\r\n    <wb:adminregion id="" iso2code="" />\r\n    <wb:incomeLevel id="NA" iso2code="NA">Aggregates</wb:incomeLevel>\r\n    <wb:lendingType id="" iso2code="">Aggregates</wb:lendingType>\r\n    <wb:capitalCity />\r\n    <wb:longitude />\r\n    <wb:latitude />\r\n  </wb:country>\r\n  <wb:country id="AFG">\r\n    <wb:iso2Code>AF</wb:iso2Code>\r\n    <wb:name>Afghanistan</wb:name>\r\n    <wb:region id="SAS" iso2code="8S">South Asia</wb:region>\r\n    <wb:adminregion id="SAS" iso2code="8S">South Asia</wb:adminregion>\r\n    <wb:incomeLevel id="LIC" iso2code="XM">Low income</wb:incomeLevel>\r\n    <wb:lendingType id="IDX" iso2code="XI">IDA</wb:lendingType>\r\n    <wb:capitalCity>Kabul</wb:capitalCity>\r\n    <wb:longitude>69.1761</wb:longitude>\r\n    <wb:latitude>34.5228</wb:latitude>\r\n  </wb:country>\r\n  <wb:country id="AFR">\r\n    <wb:iso2Code>A9</wb:iso2Code>\r\n    <wb:name>Africa</wb:name>\r\n    <wb:region id="NA" iso2code="NA">Aggregates</wb:region>\r\n    <wb:adminregion id="" iso2code="" />\r\n    <wb:incomeLevel id="NA" iso2code="NA">Aggregates</wb:incomeLevel>\r\n    <wb:lendingType id="" iso2code="">Aggregates</wb:lendingType>\r\n    <wb:capitalCity />\r\n    <wb:longitude />\r\n    <wb:latitude />\r\n  </wb:country>\r\n  <wb:country id="AFW">\r\n    <wb:iso2Code>ZI</wb:iso2Code>\r\n    <wb:name>Africa Western and Central</wb:name>\r\n    <wb:region id="NA" iso2code="NA">Aggregates</wb:region>\r\n    <wb:adminregion id="" iso2code="" />\r\n    <wb:incomeLevel id="NA" iso2code="NA">Aggregates</wb:incomeLevel>\r\n    <wb:lendingType id="" iso2code="">Aggregates</wb:lendingType>\r\n    <wb:capitalCity />\r\n    <wb:longitude />\r\n    <wb:latitude />\r\n  </wb:country>\r\n  <wb:country id="AGO">\r\n    <wb:iso2Code>AO</wb:iso2Code>\r\n    <wb:name>Angola</wb:name>\r\n    <wb:region id="SSF" iso2code="ZG">Sub-Saharan Africa </wb:region>\r\n    <wb:adminregion id="SSA" iso2code="ZF">Sub-Saharan Africa (excluding high income)</wb:adminregion>\r\n    <wb:incomeLevel id="LMC" iso2code="XN">Lower middle income</wb:incomeLevel>\r\n    <wb:lendingType id="IBD" iso2code="XF">IBRD</wb:lendingType>\r\n    <wb:capitalCity>Luanda</wb:capitalCity>\r\n    <wb:longitude>13.242</wb:longitude>\r\n    <wb:latitude>-8.81155</wb:latitude>\r\n  </wb:country>\r\n  <wb:country id="ALB">\r\n    <wb:iso2Code>AL</wb:iso2Code>\r\n    <wb:name>Albania</wb:name>\r\n    <wb:region id="ECS" iso2code="Z7">Europe &amp; Central Asia</wb:region>\r\n    <wb:adminregion id="ECA" iso2code="7E">Europe &amp; Central Asia (excluding high income)</wb:adminregion>\r\n    <wb:incomeLevel id="UMC" iso2code="XT">Upper middle income</wb:incomeLevel>\r\n    <wb:lendingType id="IBD" iso2code="XF">IBRD</wb:lendingType>\r\n    <wb:capitalCity>Tirane</wb:capitalCity>\r\n    <wb:longitude>19.8172</wb:longitude>\r\n    <wb:latitude>41.3317</wb:latitude>\r\n  </wb:country>\r\n  <wb:country id="AND">\r\n    <wb:iso2Code>AD</wb:iso2Code>\r\n    <wb:name>Andorra</wb:name>\r\n    <wb:region id="ECS" iso2code="Z7">Europe &amp; Central Asia</wb:region>\r\n    <wb:adminregion id="" iso2code="" />\r\n    <wb:incomeLevel id="HIC" is ...

# %% [markdown]
# Por defecto, la API entrega resultados en formato XML. Para obtenerlos en formato JSON, es necesario especificar
# el parámetro `format`

# %%
#Por defecto, la API entrega resultados en formato XML. Para obtenerlos en formato JSON, es necesario especificar
#el parámetro 'format'

response=requests.get(url,params={'format':'json'})
response.content
# Out:
# b'[{"page":1,"pages":6,"per_page":"50","total":297},[{"id":"ABW","iso2Code":"AW","name":"Aruba","region":{"id":"LCN","iso2code":"ZJ","value":"Latin America & Caribbean "},"adminregion":{"id":"","iso2code":"","value":""},"incomeLevel":{"id":"HIC","iso2code":"XD","value":"High income"},"lendingType":{"id":"LNX","iso2code":"XX","value":"Not classified"},"capitalCity":"Oranjestad","longitude":"-70.0167","latitude":"12.5167"},{"id":"AFE","iso2Code":"ZH","name":"Africa Eastern and Southern","region":{"id":"NA","iso2code":"NA","value":"Aggregates"},"adminregion":{"id":"","iso2code":"","value":""},"incomeLevel":{"id":"NA","iso2code":"NA","value":"Aggregates"},"lendingType":{"id":"","iso2code":"","value":"Aggregates"},"capitalCity":"","longitude":"","latitude":""},{"id":"AFG","iso2Code":"AF","name":"Afghanistan","region":{"id":"SAS","iso2code":"8S","value":"South Asia"},"adminregion":{"id":"SAS","iso2code":"8S","value":"South Asia"},"incomeLevel":{"id":"LIC","iso2code":"XM","value":"Low income"},"lendingType":{"id":"IDX","iso2code":"XI","value":"IDA"},"capitalCity":"Kabul","longitude":"69.1761","latitude":"34.5228"},{"id":"AFR","iso2Code":"A9","name":"Africa","region":{"id":"NA","iso2code":"NA","value":"Aggregates"},"adminregion":{"id":"","iso2code":"","value":""},"incomeLevel":{"id":"NA","iso2code":"NA","value":"Aggregates"},"lendingType":{"id":"","iso2code":"","value":"Aggregates"},"capitalCity":"","longitude":"","latitude":""},{"id":"AFW","iso2Code":"ZI","name":"Africa Western and Central","region":{"id":"NA","iso2code":"NA","value":"Aggregates"},"adminregion":{"id":"","iso2code":"","value":""},"incomeLevel":{"id":"NA","iso2code":"NA","value":"Aggregates"},"lendingType":{"id":"","iso2code":"","value":"Aggregates"},"capitalCity":"","longitude":"","latitude":""},{"id":"AGO","iso2Code":"AO","name":"Angola","region":{"id":"SSF","iso2code":"ZG","value":"Sub-Saharan Africa "},"adminregion":{"id":"SSA","iso2code":"ZF","value":"Sub-Saharan Africa (excluding high income)"},"incomeLevel":{"id":"LMC","iso2code":"XN","value":"Lower middle income"},"lendingType":{"id":"IBD","iso2code":"XF","value":"IBRD"},"capitalCity":"Luanda","longitude":"13.242","latitude":"-8.81155"},{"id":"ALB","iso2Code":"AL","name":"Albania","region":{"id":"ECS","iso2code":"Z7","value":"Europe & Central Asia"},"adminregion":{"id":"ECA","iso2code":"7E","value":"Europe & Central Asia (excluding high income)"},"incomeLevel":{"id":"UMC","iso2code":"XT","value":"Upper middle income"},"lendingType":{"id":"IBD","iso2code":"XF","value":"IBRD"},"capitalCity":"Tirane","longitude":"19.8172","latitude":"41.3317"},{"id":"AND","iso2Code":"AD","name":"Andorra","region":{"id":"ECS","iso2code":"Z7","value":"Europe & Central Asia"},"adminregion":{"id":"","iso2code":"","value":""},"incomeLevel":{"id":"HIC","iso2code":"XD","value":"High income"},"lendingType":{"id":"LNX","iso2code":"XX","value":"Not classified"},"capitalCity":"Andorra la Vella","longitude":"1.5218","latitude":"42.5075"},{"id":"ARB","iso2Code":"1A","name":"Arab World","region":{"id":"NA","iso2code":"NA","value":"Aggregates"},"adminregion":{"id":"","iso2code":"","value":""},"incomeLevel":{"id":"NA","iso2code":"NA","value":"Aggregates"},"lendingType":{"id":"","iso2code":"","value":"Aggregates"},"capitalCity":"","longitude":"","latitude":""},{"id":"ARE","iso2Code":"AE","name":"United Arab Emirates","region":{"id":"MEA","iso2code":"ZQ","value":"Middle East & North Africa"},"adminregion":{"id":"","iso2code":"","value":""},"incomeLevel":{"id":"HIC","iso2code":"XD","value":"High income"},"lendingType":{"id":"LNX","iso2code":"XX","value":"Not classified"},"capitalCity":"Abu Dhabi","longitude":"54.3705","latitude":"24.4764"},{"id":"ARG","iso2Code":"AR","name":"Argentina","region":{"id":"LCN","iso2code":"ZJ","value":"Latin America & Caribbean "},"adminregion":{"id":"LAC","iso2code":"XJ","value":"Latin America & Caribbean (excluding high income)"},"incomeLevel":{"id":"UMC","iso2code":"XT","value":"Upper middle income"},"lendingType":{"i ...

# %%
#incluir parámetros directamente en el string url
url_query='http://api.worldbank.org/v2/country?format=json'
response=requests.get(url_query)
response.content
# Out:
# b'[{"page":1,"pages":6,"per_page":"50","total":297},[{"id":"ABW","iso2Code":"AW","name":"Aruba","region":{"id":"LCN","iso2code":"ZJ","value":"Latin America & Caribbean "},"adminregion":{"id":"","iso2code":"","value":""},"incomeLevel":{"id":"HIC","iso2code":"XD","value":"High income"},"lendingType":{"id":"LNX","iso2code":"XX","value":"Not classified"},"capitalCity":"Oranjestad","longitude":"-70.0167","latitude":"12.5167"},{"id":"AFE","iso2Code":"ZH","name":"Africa Eastern and Southern","region":{"id":"NA","iso2code":"NA","value":"Aggregates"},"adminregion":{"id":"","iso2code":"","value":""},"incomeLevel":{"id":"NA","iso2code":"NA","value":"Aggregates"},"lendingType":{"id":"","iso2code":"","value":"Aggregates"},"capitalCity":"","longitude":"","latitude":""},{"id":"AFG","iso2Code":"AF","name":"Afghanistan","region":{"id":"SAS","iso2code":"8S","value":"South Asia"},"adminregion":{"id":"SAS","iso2code":"8S","value":"South Asia"},"incomeLevel":{"id":"LIC","iso2code":"XM","value":"Low income"},"lendingType":{"id":"IDX","iso2code":"XI","value":"IDA"},"capitalCity":"Kabul","longitude":"69.1761","latitude":"34.5228"},{"id":"AFR","iso2Code":"A9","name":"Africa","region":{"id":"NA","iso2code":"NA","value":"Aggregates"},"adminregion":{"id":"","iso2code":"","value":""},"incomeLevel":{"id":"NA","iso2code":"NA","value":"Aggregates"},"lendingType":{"id":"","iso2code":"","value":"Aggregates"},"capitalCity":"","longitude":"","latitude":""},{"id":"AFW","iso2Code":"ZI","name":"Africa Western and Central","region":{"id":"NA","iso2code":"NA","value":"Aggregates"},"adminregion":{"id":"","iso2code":"","value":""},"incomeLevel":{"id":"NA","iso2code":"NA","value":"Aggregates"},"lendingType":{"id":"","iso2code":"","value":"Aggregates"},"capitalCity":"","longitude":"","latitude":""},{"id":"AGO","iso2Code":"AO","name":"Angola","region":{"id":"SSF","iso2code":"ZG","value":"Sub-Saharan Africa "},"adminregion":{"id":"SSA","iso2code":"ZF","value":"Sub-Saharan Africa (excluding high income)"},"incomeLevel":{"id":"LMC","iso2code":"XN","value":"Lower middle income"},"lendingType":{"id":"IBD","iso2code":"XF","value":"IBRD"},"capitalCity":"Luanda","longitude":"13.242","latitude":"-8.81155"},{"id":"ALB","iso2Code":"AL","name":"Albania","region":{"id":"ECS","iso2code":"Z7","value":"Europe & Central Asia"},"adminregion":{"id":"ECA","iso2code":"7E","value":"Europe & Central Asia (excluding high income)"},"incomeLevel":{"id":"UMC","iso2code":"XT","value":"Upper middle income"},"lendingType":{"id":"IBD","iso2code":"XF","value":"IBRD"},"capitalCity":"Tirane","longitude":"19.8172","latitude":"41.3317"},{"id":"AND","iso2Code":"AD","name":"Andorra","region":{"id":"ECS","iso2code":"Z7","value":"Europe & Central Asia"},"adminregion":{"id":"","iso2code":"","value":""},"incomeLevel":{"id":"HIC","iso2code":"XD","value":"High income"},"lendingType":{"id":"LNX","iso2code":"XX","value":"Not classified"},"capitalCity":"Andorra la Vella","longitude":"1.5218","latitude":"42.5075"},{"id":"ARB","iso2Code":"1A","name":"Arab World","region":{"id":"NA","iso2code":"NA","value":"Aggregates"},"adminregion":{"id":"","iso2code":"","value":""},"incomeLevel":{"id":"NA","iso2code":"NA","value":"Aggregates"},"lendingType":{"id":"","iso2code":"","value":"Aggregates"},"capitalCity":"","longitude":"","latitude":""},{"id":"ARE","iso2Code":"AE","name":"United Arab Emirates","region":{"id":"MEA","iso2code":"ZQ","value":"Middle East & North Africa"},"adminregion":{"id":"","iso2code":"","value":""},"incomeLevel":{"id":"HIC","iso2code":"XD","value":"High income"},"lendingType":{"id":"LNX","iso2code":"XX","value":"Not classified"},"capitalCity":"Abu Dhabi","longitude":"54.3705","latitude":"24.4764"},{"id":"ARG","iso2Code":"AR","name":"Argentina","region":{"id":"LCN","iso2code":"ZJ","value":"Latin America & Caribbean "},"adminregion":{"id":"LAC","iso2code":"XJ","value":"Latin America & Caribbean (excluding high income)"},"incomeLevel":{"id":"UMC","iso2code":"XT","value":"Upper middle income"},"lendingType":{"i ...

# %% [markdown]
# Inspeccionemos ahora el contenido de la respuesta:

# %%
json_data=response.json()
json_data
# Out:
# [{'page': 1, 'pages': 6, 'per_page': '50', 'total': 297},
#  [{'id': 'ABW',
#    'iso2Code': 'AW',
#    'name': 'Aruba',
#    'region': {'id': 'LCN',
#     'iso2code': 'ZJ',
#     'value': 'Latin America & Caribbean '},
#    'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#    'incomeLevel': {'id': 'HIC', 'iso2code': 'XD', 'value': 'High income'},
#    'lendingType': {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not classified'},
#    'capitalCity': 'Oranjestad',
#    'longitude': '-70.0167',
#    'latitude': '12.5167'},
#   {'id': 'AFE',
#    'iso2Code': 'ZH',
#    'name': 'Africa Eastern and Southern',
#    'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'},
#    'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#    'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'},
#    'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'},
#    'capitalCity': '',
#    'longitude': '',
#    'latitude': ''},
#   {'id': 'AFG',
#    'iso2Code': 'AF',
#    'name': 'Afghanistan',
#    'region': {'id': 'SAS', 'iso2code': '8S', 'value': 'South Asia'},
#    'adminregion': {'id': 'SAS', 'iso2code': '8S', 'value': 'South Asia'},
#    'incomeLevel': {'id': 'LIC', 'iso2code': 'XM', 'value': 'Low income'},
#    'lendingType': {'id': 'IDX', 'iso2code': 'XI', 'value': 'IDA'},
#    'capitalCity': 'Kabul',
#    'longitude': '69.1761',
#    'latitude': '34.5228'},
#   {'id': 'AFR',
#    'iso2Code': 'A9',
#    'name': 'Africa',
#    'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'},
#    'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#    'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'},
#    'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'},
#    'capitalCity': '',
#    'longitude': '',
#    'latitude': ''},
#   {'id': 'AFW',
#    'iso2Code': 'ZI',
#    'name': 'Africa Western and Central',
#    'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'},
#    'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#    'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'},
#    'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'},
#    'capitalCity': '',
#    'longitude': '',
#    'latitude': ''},
#   {'id': 'AGO',
#    'iso2Code': 'AO',
#    'name': 'Angola',
#    'region': {'id': 'SSF', 'iso2code': 'ZG', 'value': 'Sub-Saharan Africa '},
#    'adminregion': {'id': 'SSA',
#     'iso2code': 'ZF',
#     'value': 'Sub-Saharan Africa (excluding high income)'},
#    'incomeLevel': {'id': 'LMC',
#     'iso2code': 'XN',
#     'value': 'Lower middle income'},
#    'lendingType': {'id': 'IBD', 'iso2code': 'XF', 'value': 'IBRD'},
#    'capitalCity': 'Luanda',
#    'longitude': '13.242',
#    'latitude': '-8.81155'},
#   {'id': 'ALB',
#    'iso2Code': 'AL',
#    'name': 'Albania',
#    'region': {'id': 'ECS', 'iso2code': 'Z7', 'value': 'Europe & Central Asia'},
#    'adminregion': {'id': 'ECA',
#     'iso2code': '7E',
#     'value': 'Europe & Central Asia (excluding high income)'},
#    'incomeLevel': {'id': 'UMC',
#     'iso2code': 'XT',
#     'value': 'Upper middle income'},
#    'lendingType': {'id': 'IBD', 'iso2code': 'XF', 'value': 'IBRD'},
#    'capitalCity': 'Tirane',
#    'longitude': '19.8172',
#    'latitude': '41.3317'},
#   {'id': 'AND',
#    'iso2Code': 'AD',
#    'name': 'Andorra',
#    'region': {'id': 'ECS', 'iso2code': 'Z7', 'value': 'Europe & Central Asia'},
#    'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#    'incomeLevel': {'id': 'HIC', 'iso2code': 'XD', 'value': 'High income'},
#    'lendingType': {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not classified'},
#    'capitalCity': 'Andorra la Vella',
#    'longitude': '1.5218',
#    'latitude': '42.5075'},
#   {'id': 'ARB',
#    'iso2Code': '1A',
#    'name': 'Arab World',
#    'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'},
#    'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#    'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'},
#    'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'},
#    'capitalCity': '',
#    'longitude': '',
#    'latitude': ''},
#   {'id': 'ARE',
#    'iso2Code': 'AE',
#    'name': 'United Arab Emirates',
#    'region': {'id': 'MEA',
#     'iso2code': 'ZQ',
#     'value': 'Middle East & North Africa'},
#    'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#    'incomeLevel': {'id': 'HIC', 'iso2code': 'XD', 'value': 'High income'},
#    'lendingType': {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not classified'},
#    'capitalCity': 'Abu Dhabi',
#    'longitude': '54.3705',
#    'latitude': '24.4764'},
#   {'id': 'ARG',
#    'iso2Code': 'AR',
#    'name': 'Argentina',
#    'region': {'id': 'LCN',
#     'iso2code': 'ZJ',
#     'value': 'Latin America & Caribbean '},
#    'adminregion': {'id': 'LAC',
#     'iso2code': 'XJ',
#     'value': 'Latin America & Caribbean (excluding high income)'},
#    'incomeLevel': {'id': 'UMC',
#     'iso2code': 'XT',
#     'value': 'Upper middle income'},
#    'lendingType': {'id': 'IBD', 'iso2code': 'XF', 'value': 'IBRD'},
#    'capitalCity': 'Buenos Aires',
#    'longitude': '-58.4173',
#    'latitude': '-34.6118'},
#   {'id': 'ARM',
#    'iso2Code': 'AM',
#    'name': 'Armenia',
#    'region': {'id': 'ECS', 'iso2code': 'Z7', 'value': 'Europe & Central Asia'},
#    'adminregion': {'id': 'ECA',
#     'iso2code': '7E',
#     'value': 'Europe & Central Asia (excluding high income)'},
#    'incomeLevel': {'id': 'UMC',
#     'iso2code': 'XT',
#     'value': 'Upper middle income'},
#    'lendingType': {'id': 'IBD', 'iso2code': 'XF', 'value': 'IBRD'},
#    'capitalCity': 'Yerevan',
#    'longitude': '44.509',
#    'latitude': '40.1596'},
#   {'id': 'ASM',
#    'iso2Code': 'AS',
#    'name': 'American Samoa',
#    'region': {'id': 'EAS', 'iso2code': 'Z4', 'value': 'East Asia & Pacific'},
#    'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#    'incomeLevel': {'id': 'HIC', 'iso2code': 'XD', 'value': 'High income'},
#    'lendingType': {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not classified'},
#    'capitalCity': 'Pago Pago',
#    'longitude': '-170.691',
#    'latitude': '-14.2846'},
#   {'id': 'ATG',
#    'iso2Code': 'AG',
#    'name': 'Antigua and Barbuda',
#    'region': {'id': 'LCN',
#     'iso2code': 'ZJ',
#     'value': 'Latin America & Caribbean '},
#    'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#    'incomeLevel': {'id': 'HIC', 'iso2code': 'XD', 'value': 'High income'},
#    'lendingType': {'id': 'IBD', 'iso2code': 'XF', 'value': 'IBRD'},
#    'capitalCity': "Saint John's",
#    'longitude': '-61.8456',
#    'latitude': '17.1175'},
#   {'id': 'AUS',
#    'iso2Code': 'AU',
#    'name': 'Australia',
#    'region': {'id': 'EAS', 'iso2code': 'Z4', 'value': 'East Asia & Pacific'},
#    'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#    'incomeLevel': {'id': 'HIC', 'iso2code': 'XD', 'value': 'High income'},
#    'lendingType': {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not classified'},
#    'capitalCity': 'Canberra',
#    'longitude': '149.129',
#    'latitude': '-35.282'},
#   {'id': 'AUT',
#    'iso2Code': 'AT',
#    'name': 'Austria',
#    'region': {'id': 'ECS', 'iso2code': 'Z7', 'value': 'Europe & Central Asia'},
#    'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#    'incomeLevel': {'id': 'HIC', 'iso2code': 'XD', 'value': 'High income'},
#    'lendingType': {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not classified'},
#    'capitalCity': 'Vienna',
#    'longitude': '16.3798',
#    'latitude': '48.2201'},
#   {'id': 'AZE',
#    'iso2Code': 'AZ',
#    'name': 'Azerbaijan',
#    'region': {'id': 'ECS', 'iso2code': 'Z7', 'value': 'Europe & Central Asia'},
#    'adminregion': {'id': 'ECA',
#     'iso2code': '7E',
#     'value': 'Europe & Central Asia (excluding high income)'},
#    'incomeLevel': {'id': 'UMC',
#     'iso2code': 'XT',
#     'value': 'Upper middle income'},
#    'lendingType': {'id': 'IBD', 'iso2code': 'XF', 'value': 'IBRD'},
#    'capitalCity': 'Baku',
#    'longitude': '49.8932',
#    'latitude': '40.3834'},
#   {'id': 'BDI',
#    'iso2Code': 'BI',
#    'name': 'Burundi',
#    'region': {'id': 'SSF', 'iso2code': 'ZG', 'value': 'Sub-Saharan Africa '},
#    'adminregion': {'id': 'SSA',
#     'iso2code': 'ZF',
#     'value': 'Sub-Saharan Africa (excluding high income)'},
#    'incomeLevel': {'id': 'LIC', 'iso2code': 'XM', 'value': 'Low income'},
#    'lendingType': {'id': 'IDX', 'iso2code': 'XI', 'value': 'IDA'},
#    'capitalCity': 'Bujumbura',
#    'longitude': '29.3639',
#    'latitude': '-3.3784'},
#   {'id': 'BEA',
#    'iso2Code': 'B4',
#    'name': 'East Asia & Pacific (IBRD-only countries)',
#    'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'},
#    'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#    'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'},
#    'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'},
#    'capitalCity': '',
#    'longitude': '',
#    'latitude': ''},
#   {'id': 'BEC',
#    'iso2Code': 'B7',
#    'name': 'Europe & Central Asia (IBRD-only countries)',
#    'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'},
#    'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#    'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'},
#    'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'},
#    'capitalCity': '',
#    'longitude': '',
#    'latitude': ''},
#   {'id': 'BEL',
#    'iso2Code': 'BE',
#    'name': 'Belgium',
#    'region': {'id': 'ECS', 'iso2code': 'Z7', 'value': 'Europe & Central Asia'},
#    'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#    'incomeLevel': {'id': 'HIC', 'iso2code': 'XD', 'value': 'High income'},
#    'lendingType': {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not classified'},
#    'capitalCity': 'Brussels',
#    'longitude': '4.36761',
#    'latitude': '50.8371'},
#   {'id': 'BEN',
#    'iso2Code': 'BJ',
#    'name': 'Benin',
#    'region': {'id': 'SSF', 'iso2code': 'ZG', 'value': 'Sub-Saharan Africa '},
#    'adminregion': {'id': 'SSA',
#     'iso2code': 'ZF',
#     'value': 'Sub-Saharan Africa (excluding high income)'},
#    'incomeLevel': {'id': 'LMC',
#     'iso2code': 'XN',
#     'value': 'Lower middle income'},
#    'lendingType': {'id': 'IDX', 'iso2code': 'XI', 'value': 'IDA'},
#    'capitalCity': 'Porto-Novo',
#    'longitude': '2.6323',
#    'latitude': '6.4779'},
#   {'id': 'BFA',
#    'iso2Code': 'BF',
#    'name': 'Burkina Faso',
#    'region': {'id': 'SSF', 'iso2code': 'ZG', 'value': 'Sub-Saharan Africa '},
#    'adminregion': {'id': 'SSA',
#     'iso2code': 'ZF',
#     'value': 'Sub-Saharan Africa (excluding high income)'},
#    'incomeLevel': {'id': 'LIC', 'iso2code': 'XM', 'value': 'Low income'},
#    'lendingType': {'id': 'IDX', 'iso2code': 'XI', 'value': 'IDA'},
#    'capitalCity': 'Ouagadougou',
#    'longitude': '-1.53395',
#    'latitude': '12.3605'},
#   {'id': 'BGD',
#    'iso2Code': 'BD',
#    'name': 'Bangladesh',
#    'region': {'id': 'SAS', 'iso2code': '8S', 'value': 'South Asia'},
#    'adminregion': {'id': 'SAS', 'iso2code': '8S', 'value': 'South Asia'},
#    'incomeLevel': {'id': 'LMC',
#     'iso2code': 'XN',
#     'value': 'Lower middle income'},
#    'lendingType': {'id': 'IDX', 'iso2code': 'XI', 'value': 'IDA'},
#    'capitalCity': 'Dhaka',
#    'longitude': '90.4113',
#    'latitude': '23.7055'},
#   {'id': 'BGR',
#    'iso2Code': 'BG',
#    'name': 'Bulgaria',
#    'region': {'id': 'ECS', 'iso2code': 'Z7', 'value': 'Europe & Central Asia'},
#    'adminregion': {'id': 'ECA',
#     'iso2code': '7E',
#     'value': 'Europe & Central Asia (excluding high income)'},
#    'incomeLevel': {'id': 'UMC',
#     'iso2code': 'XT',
#     'value': 'Upper middle income'},
#    'lendingType': {'id': 'IBD', 'iso2code': 'XF', 'value': 'IBRD'},
#    'capitalCity': 'Sofia',
#    'longitude': '23.3238',
#    'latitude': '42.7105'},
#   {'id': 'BHI',
#    'iso2Code': 'B1',
#    'name': 'IBRD countries classified as high income',
#    'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'},
#    'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#    'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'},
#    'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'},
#    'capitalCity': '',
#    'longitude': '',
#    'latitude': ''},
#   {'id': 'BHR',
#    'iso2Code': 'BH',
#    'name': 'Bahrain',
#    'region': {'id': 'MEA',
#     'iso2code': 'ZQ',
#     'value': 'Middle East & North Africa'},
#    'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#    'incomeLevel': {'id': 'HIC', 'iso2code': 'XD', 'value': 'High income'},
#    'lendingType': {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not classified'},
#    'capitalCity': 'Manama',
#    'longitude': '50.5354',
#    'latitude': '26.1921'},
#   {'id': 'BHS',
#    'iso2Code': 'BS',
#    'name': 'Bahamas, The',
#    'region': {'id': 'LCN',
#     'iso2code': 'ZJ',
#     'value': 'Latin America & Caribbean '},
#    'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#    'incomeLevel': {'id': 'HIC', 'iso2code': 'XD', 'value': 'High income'},
#    'lendingType': {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not classified'},
#    'capitalCity': 'Nassau',
#    'longitude': '-77.339',
#    'latitude': '25.0661'},
#   {'id': 'BIH',
#    'iso2Code': 'BA',
#    'name': 'Bosnia and Herzegovina',
#    'region': {'id': 'ECS', 'iso2code': 'Z7', 'value': 'Europe & Central Asia'},
#    'adminregion': {'id': 'ECA',
#     'iso2code': '7E',
#     'value': 'Europe & Central Asia (excluding high income)'},
#    'incomeLevel': {'id': 'UMC',
#     'iso2code': 'XT',
#     'value': 'Upper middle income'},
#    'lendingType': {'id': 'IBD', 'iso2code': 'XF', 'value': 'IBRD'},
#    'capitalCity': 'Sarajevo',
#    'longitude': '18.4214',
#    'latitude': '43.8607'},
#   {'id': 'BLA',
#    'iso2Code': 'B2',
#    'name': 'Latin America & the Caribbean (IBRD-only countries)',
#    'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'},
#    'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#    'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'},
#    'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'},
#    'capitalCity': '',
#    'longitude': '',
#    'latitude': ''},
#   {'id': 'BLR',
#    'iso2Code': 'BY',
#    'name': 'Belarus',
#    'region': {'id': 'ECS', 'iso2code': 'Z7', 'value': 'Europe & Central Asia'},
#    'adminregion': {'id': 'ECA',
#     'iso2code': '7E',
#     'value': 'Europe & Central Asia (excluding high income)'},
#    'incomeLevel': {'id': 'UMC',
#     'iso2code': 'XT',
#     'value': 'Upper middle income'},
#    'lendingType': {'id': 'IBD', 'iso2code': 'XF', 'value': 'IBRD'},
#    'capitalCity': 'Minsk',
#    'longitude': '27.5766',
#    'latitude': '53.9678'},
#   {'id': 'BLZ',
#    'iso2Code': 'BZ',
#    'name': 'Belize',
#    'region': {'id': 'LCN',
#     'iso2code': 'ZJ',
#     'value': 'Latin America & Caribbean '},
#    'adminregion': {'id': 'LAC',
#     'iso2code': 'XJ',
#     'value': 'Latin America & Caribbean (excluding high income)'},
#    'incomeLevel': {'id': 'UMC',
#     'iso2code': 'XT',
#     'value': 'Upper middle income'},
#    'lendingType': {'id': 'IBD', 'iso2code': 'XF', 'value': 'IBRD'},
#    'capitalCity': 'Belmopan',
#    'longitude': '-88.7713',
#    'latitude': '17.2534'},
#   {'id': 'BMN',
#    'iso2Code': 'B3',
#    'name': 'Middle East & North Africa (IBRD-only countries)',
#    'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'},
#    'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#    'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'},
#    'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'},
#    'capitalCity': '',
#    'longitude': '',
#    'latitude': ''},
#   {'id': 'BMU',
#    'iso2Code': 'BM',
#    'name': 'Bermuda',
#    'region': {'id': 'NAC', 'iso2code': 'XU', 'value': 'North America'},
#    'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#    'incomeLevel': {'id': 'HIC', 'iso2code': 'XD', 'value': 'High income'},
#    'lendingType': {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not classified'},
#    'capitalCity': 'Hamilton',
#    'longitude': '-64.706',
#    'latitude': '32.3293'},
#   {'id': 'BOL',
#    'iso2Code': 'BO',
#    'name': 'Bolivia',
#    'region': {'id': 'LCN',
#     'iso2code': 'ZJ',
#     'value': 'Latin America & Caribbean '},
#    'adminregion': {'id': 'LAC',
#     'iso2code': 'XJ',
#     'value': 'Latin America & Caribbean (excluding high income)'},
#    'incomeLevel': {'id': 'LMC',
#     'iso2code': 'XN',
#     'value': 'Lower middle income'},
#    'lendingType': {'id': 'IBD', 'iso2code': 'XF', 'value': 'IBRD'},
#    'capitalCity': 'La Paz',
#    'longitude': '-66.1936',
#    'latitude': '-13.9908'},
#   {'id': 'BRA',
#    'iso2Code': 'BR',
#    'name': 'Brazil',
#    'region': {'id': 'LCN',
#     'iso2code': 'ZJ',
#     'value': 'Latin America & Caribbean '},
#    'adminregion': {'id': 'LAC',
#     'iso2code': 'XJ',
#     'value': 'Latin America & Caribbean (excluding high income)'},
#    'incomeLevel': {'id': 'UMC',
#     'iso2code': 'XT',
#     'value': 'Upper middle income'},
#    'lendingType': {'id': 'IBD', 'iso2code': 'XF', 'value': 'IBRD'},
#    'capitalCity': 'Brasilia',
#    'longitude': '-47.9292',
#    'latitude': '-15.7801'},
#   {'id': 'BRB',
#    'iso2Code': 'BB',
#    'name': 'Barbados',
#    'region': {'id': 'LCN',
#     'iso2code': 'ZJ',
#     'value': 'Latin America & Caribbean '},
#    'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#    'incomeLevel': {'id': 'HIC', 'iso2code': 'XD', 'value': 'High income'},
#    'lendingType': {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not classified'},
#    'capitalCity': 'Bridgetown',
#    'longitude': '-59.6105',
#    'latitude': '13.0935'},
#   {'id': 'BRN',
#    'iso2Code': 'BN',
#    'name': 'Brunei Darussalam',
#    'region': {'id': 'EAS', 'iso2code': 'Z4', 'value': 'East Asia & Pacific'},
#    'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#    'incomeLevel': {'id': 'HIC', 'iso2code': 'XD', 'value': 'High income'},
#    'lendingType': {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not classified'},
#    'capitalCity': 'Bandar Seri Begawan',
#    'longitude': '114.946',
#    'latitude': '4.94199'},
#   {'id': 'BSS',
#    'iso2Code': 'B6',
#    'name': 'Sub-Saharan Africa (IBRD-only countries)',
#    'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'},
#    'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#    'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'},
#    'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'},
#    'capitalCity': '',
#    'longitude': '',
#    'latitude': ''},
#   {'id': 'BTN',
#    'iso2Code': 'BT',
#    'name': 'Bhutan',
#    'region': {'id': 'SAS', 'iso2code': '8S', 'value': 'South Asia'},
#    'adminregion': {'id': 'SAS', 'iso2code': '8S', 'value': 'South Asia'},
#    'incomeLevel': {'id': 'LMC',
#     'iso2code': 'XN',
#     'value': 'Lower middle income'},
#    'lendingType': {'id': 'IDX', 'iso2code': 'XI', 'value': 'IDA'},
#    'capitalCity': 'Thimphu',
#    'longitude': '89.6177',
#    'latitude': '27.5768'},
#   {'id': 'BWA',
#    'iso2Code': 'BW',
#    'name': 'Botswana',
#    'region': {'id': 'SSF', 'iso2code': 'ZG', 'value': 'Sub-Saharan Africa '},
#    'adminregion': {'id': 'SSA',
#     'iso2code': 'ZF',
#     'value': 'Sub-Saharan Africa (excluding high income)'},
#    'incomeLevel': {'id': 'UMC',
#     'iso2code': 'XT',
#     'value': 'Upper middle income'},
#    'lendingType': {'id': 'IBD', 'iso2code': 'XF', 'value': 'IBRD'},
#    'capitalCity': 'Gaborone',
#    'longitude': '25.9201',
#    'latitude': '-24.6544'},
#   {'id': 'CAA',
#    'iso2Code': 'C9',
#    'name': 'Sub-Saharan Africa (IFC classification)',
#    'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'},
#    'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#    'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'},
#    'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'},
#    'capitalCity': '',
#    'longitude': '',
#    'latitude': ''},
#   {'id': 'CAF',
#    'iso2Code': 'CF',
#    'name': 'Central African Republic',
#    'region': {'id': 'SSF', 'iso2code': 'ZG', 'value': 'Sub-Saharan Africa '},
#    'adminregion': {'id': 'SSA',
#     'iso2code': 'ZF',
#     'value': 'Sub-Saharan Africa (excluding high income)'},
#    'incomeLevel': {'id': 'LIC', 'iso2code': 'XM', 'value': 'Low income'},
#    'lendingType': {'id': 'IDX', 'iso2code': 'XI', 'value': 'IDA'},
#    'capitalCity': 'Bangui',
#    'longitude': '21.6407',
#    'latitude': '5.63056'},
#   {'id': 'CAN',
#    'iso2Code': 'CA',
#    'name': 'Canada',
#    'region': {'id': 'NAC', 'iso2code': 'XU', 'value': 'North America'},
#    'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#    'incomeLevel': {'id': 'HIC', 'iso2code': 'XD', 'value': 'High income'},
#    'lendingType': {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not classified'},
#    'capitalCity': 'Ottawa',
#    'longitude': '-75.6919',
#    'latitude': '45.4215'},
#   {'id': 'CEA',
#    'iso2Code': 'C4',
#    'name': 'East Asia and the Pacific (IFC classification)',
#    'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'},
#    'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#    'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'},
#    'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'},
#    'capitalCity': '',
#    'longitude': '',
#    'latitude': ''},
#   {'id': 'CEB',
#    'iso2Code': 'B8',
#    'name': 'Central Europe and the Baltics',
#    'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'},
#    'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#    'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'},
#    'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'},
#    'capitalCity': '',
#    'longitude': '',
#    'latitude': ''},
#   {'id': 'CEU',
#    'iso2Code': 'C5',
#    'name': 'Europe and Central Asia (IFC classification)',
#    'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'},
#    'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#    'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'},
#    'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'},
#    'capitalCity': '',
#    'longitude': '',
#    'latitude': ''},
#   {'id': 'CHE',
#    'iso2Code': 'CH',
#    'name': 'Switzerland',
#    'region': {'id': 'ECS', 'iso2code': 'Z7', 'value': 'Europe & Central Asia'},
#    'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#    'incomeLevel': {'id': 'HIC', 'iso2code': 'XD', 'value': 'High income'},
#    'lendingType': {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not classified'},
#    'capitalCity': 'Bern',
#    'longitude': '7.44821',
#    'latitude': '46.948'},
#   {'id': 'CHI',
#    'iso2Code': 'JG',
#    'name': 'Channel Islands',
#    'region': {'id': 'ECS', 'iso2code': 'Z7', 'value': 'Europe & Central Asia'},
#    'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#    'incomeLevel': {'id': 'HIC', 'iso2code': 'XD', 'value': 'High income'},
#    'lendingType': {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not classified'},
#    'capitalCity': '',
#    'longitude': '',
#    'latitude': ''},
#   {'id': 'CHL',
#    'iso2Code': 'CL',
#    'name': 'Chile',
#    'region': {'id': 'LCN',
#     'iso2code': 'ZJ',
#     'value': 'Latin America & Caribbean '},
#    'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#    'incomeLevel': {'id': 'HIC', 'iso2code': 'XD', 'value': 'High income'},
#    'lendingType': {'id': 'IBD', 'iso2code': 'XF', 'value': 'IBRD'},
#    'capitalCity': 'Santiago',
#    'longitude': '-70.6475',
#    'latitude': '-33.475'}]]

# %%
type(json_data)
# Out:
# list

# %%
print(json_data[1])
# Out:
# [{'id': 'ABW', 'iso2Code': 'AW', 'name': 'Aruba', 'region': {'id': 'LCN', 'iso2code': 'ZJ', 'value': 'Latin America & Caribbean '}, 'adminregion': {'id': '', 'iso2code': '', 'value': ''}, 'incomeLevel': {'id': 'HIC', 'iso2code': 'XD', 'value': 'High income'}, 'lendingType': {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not classified'}, 'capitalCity': 'Oranjestad', 'longitude': '-70.0167', 'latitude': '12.5167'}, {'id': 'AFE', 'iso2Code': 'ZH', 'name': 'Africa Eastern and Southern', 'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}, 'adminregion': {'id': '', 'iso2code': '', 'value': ''}, 'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}, 'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'}, 'capitalCity': '', 'longitude': '', 'latitude': ''}, {'id': 'AFG', 'iso2Code': 'AF', 'name': 'Afghanistan', 'region': {'id': 'SAS', 'iso2code': '8S', 'value': 'South Asia'}, 'adminregion': {'id': 'SAS', 'iso2code': '8S', 'value': 'South Asia'}, 'incomeLevel': {'id': 'LIC', 'iso2code': 'XM', 'value': 'Low income'}, 'lendingType': {'id': 'IDX', 'iso2code': 'XI', 'value': 'IDA'}, 'capitalCity': 'Kabul', 'longitude': '69.1761', 'latitude': '34.5228'}, {'id': 'AFR', 'iso2Code': 'A9', 'name': 'Africa', 'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}, 'adminregion': {'id': '', 'iso2code': '', 'value': ''}, 'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}, 'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'}, 'capitalCity': '', 'longitude': '', 'latitude': ''}, {'id': 'AFW', 'iso2Code': 'ZI', 'name': 'Africa Western and Central', 'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}, 'adminregion': {'id': '', 'iso2code': '', 'value': ''}, 'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}, 'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'}, 'capitalCity': '', 'longitude': '', 'latitude': ''}, {'id': 'AGO', 'iso2Code': 'AO', 'name': 'Angola', 'region': {'id': 'SSF', 'iso2code': 'ZG', 'value': 'Sub-Saharan Africa '}, 'adminregion': {'id': 'SSA', 'iso2code': 'ZF', 'value': 'Sub-Saharan Africa (excluding high income)'}, 'incomeLevel': {'id': 'LMC', 'iso2code': 'XN', 'value': 'Lower middle income'}, 'lendingType': {'id': 'IBD', 'iso2code': 'XF', 'value': 'IBRD'}, 'capitalCity': 'Luanda', 'longitude': '13.242', 'latitude': '-8.81155'}, {'id': 'ALB', 'iso2Code': 'AL', 'name': 'Albania', 'region': {'id': 'ECS', 'iso2code': 'Z7', 'value': 'Europe & Central Asia'}, 'adminregion': {'id': 'ECA', 'iso2code': '7E', 'value': 'Europe & Central Asia (excluding high income)'}, 'incomeLevel': {'id': 'UMC', 'iso2code': 'XT', 'value': 'Upper middle income'}, 'lendingType': {'id': 'IBD', 'iso2code': 'XF', 'value': 'IBRD'}, 'capitalCity': 'Tirane', 'longitude': '19.8172', 'latitude': '41.3317'}, {'id': 'AND', 'iso2Code': 'AD', 'name': 'Andorra', 'region': {'id': 'ECS', 'iso2code': 'Z7', 'value': 'Europe & Central Asia'}, 'adminregion': {'id': '', 'iso2code': '', 'value': ''}, 'incomeLevel': {'id': 'HIC', 'iso2code': 'XD', 'value': 'High income'}, 'lendingType': {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not classified'}, 'capitalCity': 'Andorra la Vella', 'longitude': '1.5218', 'latitude': '42.5075'}, {'id': 'ARB', 'iso2Code': '1A', 'name': 'Arab World', 'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}, 'adminregion': {'id': '', 'iso2code': '', 'value': ''}, 'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}, 'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'}, 'capitalCity': '', 'longitude': '', 'latitude': ''}, {'id': 'ARE', 'iso2Code': 'AE', 'name': 'United Arab Emirates', 'region': {'id': 'MEA', 'iso2code': 'ZQ', 'value': 'Middle East & North Africa'}, 'adminregion': {'id': '', 'iso2code': '', 'value': ''}, 'incomeLevel': {'id': 'HIC', 'iso2code': 'XD', 'value': 'High income'}, 'lendingType': {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not classified'}, 'capitalCity': 'Abu Dhabi', 'longitude': '5 ...

# %% [markdown]
# La respuesta de la API es una lista de diccionarios. El primero de ellos contiene información general de los datos, y el segundo contiene los datos de interés relativos a países.

# %%
print(json_data[0],'\n',json_data[1])
# Out:
# {'page': 1, 'pages': 6, 'per_page': '50', 'total': 297}
#  [{'id': 'ABW', 'iso2Code': 'AW', 'name': 'Aruba', 'region': {'id': 'LCN', 'iso2code': 'ZJ', 'value': 'Latin America & Caribbean '}, 'adminregion': {'id': '', 'iso2code': '', 'value': ''}, 'incomeLevel': {'id': 'HIC', 'iso2code': 'XD', 'value': 'High income'}, 'lendingType': {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not classified'}, 'capitalCity': 'Oranjestad', 'longitude': '-70.0167', 'latitude': '12.5167'}, {'id': 'AFE', 'iso2Code': 'ZH', 'name': 'Africa Eastern and Southern', 'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}, 'adminregion': {'id': '', 'iso2code': '', 'value': ''}, 'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}, 'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'}, 'capitalCity': '', 'longitude': '', 'latitude': ''}, {'id': 'AFG', 'iso2Code': 'AF', 'name': 'Afghanistan', 'region': {'id': 'SAS', 'iso2code': '8S', 'value': 'South Asia'}, 'adminregion': {'id': 'SAS', 'iso2code': '8S', 'value': 'South Asia'}, 'incomeLevel': {'id': 'LIC', 'iso2code': 'XM', 'value': 'Low income'}, 'lendingType': {'id': 'IDX', 'iso2code': 'XI', 'value': 'IDA'}, 'capitalCity': 'Kabul', 'longitude': '69.1761', 'latitude': '34.5228'}, {'id': 'AFR', 'iso2Code': 'A9', 'name': 'Africa', 'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}, 'adminregion': {'id': '', 'iso2code': '', 'value': ''}, 'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}, 'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'}, 'capitalCity': '', 'longitude': '', 'latitude': ''}, {'id': 'AFW', 'iso2Code': 'ZI', 'name': 'Africa Western and Central', 'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}, 'adminregion': {'id': '', 'iso2code': '', 'value': ''}, 'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}, 'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'}, 'capitalCity': '', 'longitude': '', 'latitude': ''}, {'id': 'AGO', 'iso2Code': 'AO', 'name': 'Angola', 'region': {'id': 'SSF', 'iso2code': 'ZG', 'value': 'Sub-Saharan Africa '}, 'adminregion': {'id': 'SSA', 'iso2code': 'ZF', 'value': 'Sub-Saharan Africa (excluding high income)'}, 'incomeLevel': {'id': 'LMC', 'iso2code': 'XN', 'value': 'Lower middle income'}, 'lendingType': {'id': 'IBD', 'iso2code': 'XF', 'value': 'IBRD'}, 'capitalCity': 'Luanda', 'longitude': '13.242', 'latitude': '-8.81155'}, {'id': 'ALB', 'iso2Code': 'AL', 'name': 'Albania', 'region': {'id': 'ECS', 'iso2code': 'Z7', 'value': 'Europe & Central Asia'}, 'adminregion': {'id': 'ECA', 'iso2code': '7E', 'value': 'Europe & Central Asia (excluding high income)'}, 'incomeLevel': {'id': 'UMC', 'iso2code': 'XT', 'value': 'Upper middle income'}, 'lendingType': {'id': 'IBD', 'iso2code': 'XF', 'value': 'IBRD'}, 'capitalCity': 'Tirane', 'longitude': '19.8172', 'latitude': '41.3317'}, {'id': 'AND', 'iso2Code': 'AD', 'name': 'Andorra', 'region': {'id': 'ECS', 'iso2code': 'Z7', 'value': 'Europe & Central Asia'}, 'adminregion': {'id': '', 'iso2code': '', 'value': ''}, 'incomeLevel': {'id': 'HIC', 'iso2code': 'XD', 'value': 'High income'}, 'lendingType': {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not classified'}, 'capitalCity': 'Andorra la Vella', 'longitude': '1.5218', 'latitude': '42.5075'}, {'id': 'ARB', 'iso2Code': '1A', 'name': 'Arab World', 'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}, 'adminregion': {'id': '', 'iso2code': '', 'value': ''}, 'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}, 'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'}, 'capitalCity': '', 'longitude': '', 'latitude': ''}, {'id': 'ARE', 'iso2Code': 'AE', 'name': 'United Arab Emirates', 'region': {'id': 'MEA', 'iso2code': 'ZQ', 'value': 'Middle East & North Africa'}, 'adminregion': {'id': '', 'iso2code': '', 'value': ''}, 'incomeLevel': {'id': 'HIC', 'iso2code': 'XD', 'value': 'High income'}, 'lendingType': {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not classified'}, 'capitalCity': 'Abu Dhabi', 'longitude': ' ...

# %%
#Podemos llevar estos datos a un DataFrame de pandas
df=pd.DataFrame(json_data[1]) #el primer elemento de la lista es el nombre de las columnas del DataFrame y el segundo es el 
                         #contenido de los datos en sí mismo (en formato lista de diccionarios) 
df.head()
# Out:
#     id iso2Code                         name  \
# 0  ABW       AW                        Aruba
# 1  AFE       ZH  Africa Eastern and Southern
# 2  AFG       AF                  Afghanistan
# 3  AFR       A9                       Africa
# 4  AFW       ZI   Africa Western and Central
#
#                                               region  \
# 0  {'id': 'LCN', 'iso2code': 'ZJ', 'value': 'Lati...
# 1  {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggre...
# 2  {'id': 'SAS', 'iso2code': '8S', 'value': 'Sout...
# 3  {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggre...
# 4  {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggre...
#
#                                          adminregion  \
# 0            {'id': '', 'iso2code': '', 'value': ''}
# 1            {'id': '', 'iso2code': '', 'value': ''}
# 2  {'id': 'SAS', 'iso2code': '8S', 'value': 'Sout...
# 3            {'id': '', 'iso2code': '', 'value': ''}
# 4            {'id': '', 'iso2code': '', 'value': ''}
#
#                                          incomeLevel  \
# 0  {'id': 'HIC', 'iso2code': 'XD', 'value': 'High...
# 1  {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggre...
# 2  {'id': 'LIC', 'iso2code': 'XM', 'value': 'Low ...
# 3  {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggre...
# 4  {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggre...
#
#                                          lendingType capitalCity longitude  \
# 0  {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not ...  Oranjestad  -70.0167
# 1  {'id': '', 'iso2code': '', 'value': 'Aggregates'}
# 2    {'id': 'IDX', 'iso2code': 'XI', 'value': 'IDA'}       Kabul   69.1761
# 3  {'id': '', 'iso2code': '', 'value': 'Aggregates'}
# 4  {'id': '', 'iso2code': '', 'value': 'Aggregates'}
#
#   latitude
# 0  12.5167
# 1
# 2  34.5228
# 3
# 4

# %% [markdown]
# Dado que los datos contienen diccionarios anidados, es necesario usar la función `json_normalize`para generar un DataFrame aplanado.

# %%
df=pd.json_normalize(json_data[1]) # json_normalize es una función que permite convertir un json en un DataFrame de pandas de forma más directa que la anterior
df.head()
# Out:
#     id iso2Code                         name capitalCity longitude latitude  \
# 0  ABW       AW                        Aruba  Oranjestad  -70.0167  12.5167
# 1  AFE       ZH  Africa Eastern and Southern
# 2  AFG       AF                  Afghanistan       Kabul   69.1761  34.5228
# 3  AFR       A9                       Africa
# 4  AFW       ZI   Africa Western and Central
#
#   region.id region.iso2code                region.value adminregion.id  \
# 0       LCN              ZJ  Latin America & Caribbean
# 1        NA              NA                  Aggregates
# 2       SAS              8S                  South Asia            SAS
# 3        NA              NA                  Aggregates
# 4        NA              NA                  Aggregates
#
#   adminregion.iso2code adminregion.value incomeLevel.id incomeLevel.iso2code  \
# 0                                                   HIC                   XD
# 1                                                    NA                   NA
# 2                   8S        South Asia            LIC                   XM
# 3                                                    NA                   NA
# 4                                                    NA                   NA
#
#   incomeLevel.value lendingType.id lendingType.iso2code lendingType.value
# 0       High income            LNX                   XX    Not classified
# 1        Aggregates                                            Aggregates
# 2        Low income            IDX                   XI               IDA
# 3        Aggregates                                            Aggregates
# 4        Aggregates                                            Aggregates

# %% [markdown]
# Podemos repetir el ejercicio completo para una consulta más específica, por ejemplo, solicitando sólo la información de los países de bajo nivel de ingresos (Low Income Country). De acuerdo a la documentación de la API, esto requiere definir el parámetro `incomeLevel=LIC`

# %%
response=requests.get(url,params={'format':'json','incomeLevel':'LIC'}) # Podemos incluir parámetros en la query para filtrar 
                                                                        #los resultados que nos entrega la API
json=response.json() # json es una lista de dos elementos: el primero es el nombre de las columnas del DataFrame y el segundo es el 
df2=pd.json_normalize(json[1]) #contenido de los datos en sí mismo (en formato lista de diccionarios) 
df2.head(5)
# Out:
#     id iso2Code                      name  capitalCity longitude latitude  \
# 0  AFG       AF               Afghanistan        Kabul   69.1761  34.5228
# 1  BDI       BI                   Burundi    Bujumbura   29.3639  -3.3784
# 2  BFA       BF              Burkina Faso  Ouagadougou  -1.53395  12.3605
# 3  CAF       CF  Central African Republic       Bangui   21.6407  5.63056
# 4  COD       CD          Congo, Dem. Rep.     Kinshasa   15.3222   -4.325
#
#   region.id region.iso2code         region.value adminregion.id  \
# 0       SAS              8S           South Asia            SAS
# 1       SSF              ZG  Sub-Saharan Africa             SSA
# 2       SSF              ZG  Sub-Saharan Africa             SSA
# 3       SSF              ZG  Sub-Saharan Africa             SSA
# 4       SSF              ZG  Sub-Saharan Africa             SSA
#
#   adminregion.iso2code                           adminregion.value  \
# 0                   8S                                  South Asia
# 1                   ZF  Sub-Saharan Africa (excluding high income)
# 2                   ZF  Sub-Saharan Africa (excluding high income)
# 3                   ZF  Sub-Saharan Africa (excluding high income)
# 4                   ZF  Sub-Saharan Africa (excluding high income)
#
#   incomeLevel.id incomeLevel.iso2code incomeLevel.value lendingType.id  \
# 0            LIC                   XM        Low income            IDX
# 1            LIC                   XM        Low income            IDX
# 2            LIC                   XM        Low income            IDX
# 3            LIC                   XM        Low income            IDX
# 4            LIC                   XM        Low income            IDX
#
#   lendingType.iso2code lendingType.value
# 0                   XI               IDA
# 1                   XI               IDA
# 2                   XI               IDA
# 3                   XI               IDA
# 4                   XI               IDA

# %% [markdown]
# ## Ejemplo 2: API Yelp Fusion ¿Dónde puedo comer en Santiago?
#
# La aplicación Yelp permite a los usuarios calificar y enviar comentarios sobre distintos negocios, y disponibiliza esta información mediante un conjunto de APIs.
#
# https://www.yelp.com/developers/documentation/v3/get_started
#
# Para conectarse a estas APIs, se requiere una clave privada de autentificación (gratuita), que puede ser creada siguiendo las instrucciones en:
#
# https://www.yelp.com/developers/documentation/v3/authentication
#
# En esje ejmplo, usaremos la API *Businesses Search* para obtenre un listado de restaurants en la ciudad de Santiago. La información requerida para hacer la búsqueda está disponible en:
#
# https://www.yelp.com/developers/documentation/v3/business_search
#
# Una característica importante de la API, es que entrega un **máximo de 1000 resultados**. Además, cada query tiene un límite de 50 resultados. Por lo tanto, es necesario **iterar y realizar varias queries para obtener el máximo de 1000 registros**. Para esto, se utiliza el parámetro `offset`, que permite ir avanzando en la lista.

# %%
#url de la API
api_url='https://api.yelp.com/v3/businesses/search'

#estos datos corresponden a una cuenta de usuario creada previamente
clientid='GWOCZh9-BmZxtdsAjr7Gug'
apikey='FHVvXoNmTXIl9DuxYis7AV5uLPujm9MLwrhgs5NgvCfaOxd3V6mxt6dQU8eEqYJiGxe816XATx7ufWjbMWqbV-2Uku1jxBJv8BGRC74NroLPl27PDQqs0tDixit-YHYx'
headers={'Authorization':'Bearer %s'%apikey}

# %%
params={'term':'restaurants','location':'RM Santiago, Chile','limit':50}
response=requests.get(api_url,params=params,headers=headers) #realizamos la consulta a la API con los parámetros definidos anteriormente 
data=response.json() #obtenemos los datos en formato json 
data
# Out:
# {'businesses': [{'id': '8N6Y3HsLXHBeFwhlO0YxwQ',
#    'alias': 'barrica-94-santiago',
#    'name': 'Barrica 94',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/QXbJCQglsDKGTaCOkmcvIA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/barrica-94-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 77,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'chilean', 'title': 'Chilean'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': -33.4342880070125,
#     'longitude': -70.6352240592241},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': 'Bellavista 052',
#     'address2': '',
#     'address3': '',
#     'city': 'Santiago',
#     'zip_code': '8320000',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['Bellavista 052', 'RM 8320000 Santiago', 'Chile']},
#    'phone': '+5627324939',
#    'display_phone': '+56 27324939',
#    'distance': 1395.7350189410245},
#   {'id': 'y2FR-JBGie4wiW6RjtKLhg',
#    'alias': 'aquí-está-coco-santiago',
#    'name': 'Aquí Está Coco',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/W9lFJpoTKj4xXVjw_hQY9A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/aqu%C3%AD-est%C3%A1-coco-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 57,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': -33.42406349, 'longitude': -70.61662393},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': 'La Concepción 236',
#     'address2': None,
#     'address3': None,
#     'city': 'Santiago',
#     'zip_code': None,
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['La Concepción 236', 'RM Santiago', 'Chile']},
#    'phone': '+5624106200',
#    'display_phone': '+56 24106200',
#    'distance': 2366.370671235577},
#   {'id': 'U15KdCy6HH05WISNtN9plQ',
#    'alias': 'restaurant-peumayén-santiago',
#    'name': 'Restaurant Peumayén',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/wkJAtF3Z4X5FUw5CR4c7tg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/restaurant-peumay%C3%A9n-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 71,
#    'categories': [{'alias': 'latin', 'title': 'Latin American'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': -33.4328073, 'longitude': -70.6348213},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': 'Constitución 136',
#     'address2': '',
#     'address3': '',
#     'city': 'Santiago',
#     'zip_code': '7500000',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['Constitución 136', 'RM 7500000 Santiago', 'Chile']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1504.863539969912},
#   {'id': 'LGwEqYL0reUsRdtqE44ITQ',
#    'alias': 'chipe-libre-república-independiente-del-pisco-santiago-2',
#    'name': 'Chipe Libre - República Independiente del Pisco',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/poKwCUHwy7ThWSbBTSOAFA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chipe-libre-rep%C3%BAblica-independiente-del-pisco-santiago-2?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 73,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'peruvian', 'title': 'Peruvian'},
#     {'alias': 'chilean', 'title': 'Chilean'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': -33.4383392, 'longitude': -70.6411438},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': 'José Victorino Lastarria 282',
#     'address2': '',
#     'address3': '',
#     'city': 'Santiago',
#     'zip_code': '8320156',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['José Victorino Lastarria 282',
#      'RM 8320156 Santiago',
#      'Chile']},
#    'phone': '+56226640584',
#    'display_phone': '+56 2 2664 0584',
#    'distance': 1568.1348862352445},
#   {'id': 'kEJ3b72MKnXtTGEGqXOy7w',
#    'alias': 'confitería-torres-santiago-2',
#    'name': 'Confitería Torres',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/CnBmm2eIdZAq4q8GHcmefQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/confiter%C3%ADa-torres-santiago-2?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 27,
#    'categories': [{'alias': 'chilean', 'title': 'Chilean'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': -33.4141366, 'longitude': -70.5998601},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': 'Isidora Goyenechea 2962',
#     'address2': '',
#     'address3': '',
#     'city': 'Santiago',
#     'zip_code': '7550000',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['Isidora Goyenechea 2962',
#      'RM 7550000 Santiago',
#      'Chile']},
#    'phone': '+56223332639',
#    'display_phone': '+56 2 2333 2639',
#    'distance': 4090.222251189459},
#   {'id': 'D7aZ9ZGpnyObEawvMsXi_A',
#    'alias': 'liguria-santiago-5',
#    'name': 'Liguria',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/5ANiJhZDUqkF0F_htgLtnA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/liguria-santiago-5?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 29,
#    'categories': [{'alias': 'chilean', 'title': 'Chilean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': -33.418295, 'longitude': -70.6028055},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': 'Luis Thayer Ojeda 019',
#     'address2': None,
#     'address3': None,
#     'city': 'Santiago',
#     'zip_code': '7500000',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['Luis Thayer Ojeda 019',
#      'RM 7500000 Santiago',
#      'Chile']},
#    'phone': '+56222311393',
#    'display_phone': '+56 2 2231 1393',
#    'distance': 3555.6174257192474},
#   {'id': 'KQ2D3gs9y0wIuTqoKOHO4w',
#    'alias': 'mestizo-santiago',
#    'name': 'Mestizo',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/GV-sn6fGs1JteFYHxzHK6A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mestizo-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 56,
#    'categories': [{'alias': 'chilean', 'title': 'Chilean'},
#     {'alias': 'international', 'title': 'International'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': -33.394083457956,
#     'longitude': -70.600033248157},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': 'Av. del Bicentenario 4050',
#     'address2': None,
#     'address3': None,
#     'city': 'Santiago',
#     'zip_code': '8320000',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['Av. del Bicentenario 4050',
#      'RM 8320000 Santiago',
#      'Chile']},
#    'phone': '+56974776093',
#    'display_phone': '+56 9 7477 6093',
#    'distance': 6034.856264954543},
#   {'id': 'ffHk4q3jDiMrTMLLU6kcIA',
#    'alias': 'tiramisú-santiago-2',
#    'name': 'Tiramisú',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-RWxoc49-13rEggEA-T8vQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tiramis%C3%BA-santiago-2?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 100,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': -33.414562406985,
#     'longitude': -70.597506713488},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': 'Av. Isidora Goyenechea 3141',
#     'address2': None,
#     'address3': None,
#     'city': 'Santiago',
#     'zip_code': '7550000',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['Av. Isidora Goyenechea 3141',
#      'RM 7550000 Santiago',
#      'Chile']},
#    'phone': '+56225194900',
#    'display_phone': '+56 2 2519 4900',
#    'distance': 4184.612745348328},
#   {'id': 'CAFL80wAGOMcPrEO6uMnkA',
#    'alias': 'fuente-alemana-santiago-2',
#    'name': 'Fuente Alemana',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ybpl5_bbk0tbaFEAOxFRNw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fuente-alemana-santiago-2?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 57,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': -33.4375198417072,
#     'longitude': -70.6360235448149},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': "Av. Libertador Bernardo O'Higgins 58",
#     'address2': None,
#     'address3': None,
#     'city': 'Santiago',
#     'zip_code': '8320000',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ["Av. Libertador Bernardo O'Higgins 58",
#      'RM 8320000 Santiago',
#      'Chile']},
#    'phone': '+5626393231',
#    'display_phone': '+56 26393231',
#    'distance': 1200.383671071289},
#   {'id': 'Qtni8AS93H71AfyDIsijZg',
#    'alias': 'casaluz-santiago-4',
#    'name': 'Casaluz',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/54t0O8-f3lE3sSMzYfX6cw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/casaluz-santiago-4?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 26,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': -33.442185, 'longitude': -70.626424},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': 'Av. Italia 805',
#     'address2': '',
#     'address3': '',
#     'city': 'Santiago',
#     'zip_code': '7501184',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['Av. Italia 805', 'RM 7501184 Santiago', 'Chile']},
#    'phone': '+56229187204',
#    'display_phone': '+56 2 2918 7204',
#    'distance': 210.91869264079745},
#   {'id': 'TmD9C8IRlvubHa-_AeK-wg',
#    'alias': 'california-cantina-santiago',
#    'name': 'California Cantina',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/7eXTRP2rDKDZd1VKkH5Hxw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/california-cantina-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 53,
#    'categories': [{'alias': 'sportsbars', 'title': 'Sports Bars'},
#     {'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': -33.42242, 'longitude': -70.611942},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': 'Las Urbinas 44',
#     'address2': '',
#     'address3': '',
#     'city': 'Santiago',
#     'zip_code': '7510105',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['Las Urbinas 44', 'RM 7510105 Santiago', 'Chile']},
#    'phone': '+56962493041',
#    'display_phone': '+56 9 6249 3041',
#    'distance': 2712.64205254666},
#   {'id': '9L7D68rsmWKp3ynU8xA4TQ',
#    'alias': 'la-mar-santiago',
#    'name': 'La Mar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/tlsRecrJZzhcyPOxiPptrw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-mar-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 39,
#    'categories': [{'alias': 'peruvian', 'title': 'Peruvian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': -33.3997243, 'longitude': -70.5909546},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': 'Av. Nueva Costanera 4076',
#     'address2': '',
#     'address3': '',
#     'city': 'Santiago',
#     'zip_code': '7630000',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['Av. Nueva Costanera 4076',
#      'RM 7630000 Santiago',
#      'Chile']},
#    'phone': '+56222067839',
#    'display_phone': '+56 2 2206 7839',
#    'distance': 5879.6278181647995},
#   {'id': 'pIaTdO4k6MDcin_I4SF6ig',
#    'alias': 'biwon-santiago',
#    'name': 'Biwon',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/iLRzKIuvuigCTPQ2h2HGzg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/biwon-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 3,
#    'categories': [{'alias': 'korean', 'title': 'Korean'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': -33.4223375, 'longitude': -70.6053371},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': 'Coronel 2376',
#     'address2': 'Providencia',
#     'address3': '',
#     'city': 'Santiago',
#     'zip_code': '',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['Coronel 2376',
#      'Providencia',
#      'RM Santiago',
#      'Chile']},
#    'phone': '+56229518000',
#    'display_phone': '+56 2 2951 8000',
#    'distance': 3055.675313074462},
#   {'id': 'x4R6h8NqBQmEp-tAnyFO3g',
#    'alias': 'castillo-forestal-santiago',
#    'name': 'Castillo Forestal',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ToIFZdvL4LsQqx8s40u32w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/castillo-forestal-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 19,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'chilean', 'title': 'Chilean'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': -33.4348361156787,
#     'longitude': -70.642646313429},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': 'Av. Cardenal José María Caro 390',
#     'address2': '',
#     'address3': '',
#     'city': 'Santiago',
#     'zip_code': '8320000',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['Av. Cardenal José María Caro 390',
#      'RM 8320000 Santiago',
#      'Chile']},
#    'phone': '+56226641544',
#    'display_phone': '+56 2 2664 1544',
#    'distance': 1875.8476195894168},
#   {'id': 'IUBOvOYsrcyRMdp8V2O06g',
#    'alias': 'la-diana-santiago',
#    'name': 'La Diana',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/RDs9-jGAOXcwittq038xWQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-diana-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 13,
#    'categories': [{'alias': 'brasseries', 'title': 'Brasseries'},
#     {'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'latin', 'title': 'Latin American'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': -33.450898, 'longitude': -70.649611},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': 'Arturo Prat 435',
#     'address2': '',
#     'address3': '',
#     'city': 'Santiago',
#     'zip_code': '8320000',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['Arturo Prat 435', 'RM 8320000 Santiago', 'Chile']},
#    'phone': '+56226649018',
#    'display_phone': '+56 2 2664 9018',
#    'distance': 2353.060860197377},
#   {'id': 'EG1MtnU1CapiqemCj9gPDg',
#    'alias': 'la-hacienda-gaucha-santiago-2',
#    'name': 'La Hacienda Gaucha',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/YiUIO9cx1MLEXR5WakCR_A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-hacienda-gaucha-santiago-2?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 13,
#    'categories': [{'alias': 'bbq', 'title': 'Barbeque'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': -33.4386931069913,
#     'longitude': -70.6081252589997},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': 'Pedro de Valdivia 1719',
#     'address2': '',
#     'address3': '',
#     'city': 'Santiago',
#     'zip_code': '7810000',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['Pedro de Valdivia 1719',
#      'RM 7810000 Santiago',
#      'Chile']},
#    'phone': '+5622235305',
#    'display_phone': '+56 22235305',
#    'distance': 1728.418689590485},
#   {'id': 'pCgqgk_aHrSrV-Hg0qjZfw',
#    'alias': 'karai-las-condes',
#    'name': 'Karai',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/fUBbyQKQNOmIPIwXN2NwZA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/karai-las-condes?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 14,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'peruvian', 'title': 'Peruvian'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': -33.41401, 'longitude': -70.598254},
#    'transactions': [],
#    'location': {'address1': 'Isidora Goyenechea 3000',
#     'address2': '',
#     'address3': None,
#     'city': 'Las Condes',
#     'zip_code': '',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['Isidora Goyenechea 3000', 'RM Las Condes', 'Chile']},
#    'phone': '+56227700081',
#    'display_phone': '+56 2 2770 0081',
#    'distance': 4190.356945819561},
#   {'id': 'FJcBzuQrcQkNWcfpcqcV3Q',
#    'alias': 'shinsei-vitacura',
#    'name': 'Shinsei',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/s49XqHx0hJ7r_mZkIM-22A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/shinsei-vitacura?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 3,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'nikkei', 'title': 'Nikkei'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': -33.40285, 'longitude': -70.58438},
#    'transactions': [],
#    'location': {'address1': 'Av. Presidente Kennedy 4700',
#     'address2': '',
#     'address3': None,
#     'city': 'Vitacura',
#     'zip_code': '',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['Av. Presidente Kennedy 4700',
#      'RM Vitacura',
#      'Chile']},
#    'phone': '+56226788864',
#    'display_phone': '+56 2 2678 8864',
#    'distance': 5985.2257868397355},
#   {'id': 'LyUwbW2c_0TpaYLp1tY0Gg',
#    'alias': 'el-camino-santiago',
#    'name': 'El Camino',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ZqtwXiubcFQUvhFO3jqLtg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-camino-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 12,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'bbq', 'title': 'Barbeque'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': -33.44413, 'longitude': -70.62555},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': 'Av. Italia 1034',
#     'address2': None,
#     'address3': '',
#     'city': 'Santiago',
#     'zip_code': '7501297',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['Av. Italia 1034', 'RM 7501297 Santiago', 'Chile']},
#    'phone': '+56229860765',
#    'display_phone': '+56 2 2986 0765',
#    'distance': 20.226421392849538},
#   {'id': 'lo8nbta9XAXYDmSNglDytA',
#    'alias': 'rishtedar-santiago',
#    'name': 'Rishtedar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/0ZN05aQa9N6CcjkLy8ZdeQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rishtedar-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 28,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': -33.4206034617984,
#     'longitude': -70.6036070962787},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': 'Av. Holanda 160',
#     'address2': None,
#     'address3': None,
#     'city': 'Santiago',
#     'zip_code': '7500000',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['Av. Holanda 160', 'RM 7500000 Santiago', 'Chile']},
#    'phone': '+56222313257',
#    'display_phone': '+56 2 2231 3257',
#    'distance': 3306.4843940255814},
#   {'id': 'P0eaVPMLwFXK-RC8jB1RgQ',
#    'alias': 'liguria-santiago',
#    'name': 'Liguria',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/nCCeg-D47CdH5gBXPyjh9A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/liguria-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 20,
#    'categories': [{'alias': 'chilean', 'title': 'Chilean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': -33.4230685659973,
#     'longitude': -70.6127871917753},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': 'Av. Pedro de Valdivia 47',
#     'address2': None,
#     'address3': None,
#     'city': 'Santiago',
#     'zip_code': '',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['Av. Pedro de Valdivia 47', 'RM Santiago', 'Chile']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2612.4091994520086},
#   {'id': 'DUbB2zPmssqzUTdQGcWKvQ',
#    'alias': 'da-noi-santiago',
#    'name': 'Da Noi',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Gz3KYYF9ISTyshhp3QTsig/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/da-noi-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 14,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'trattorie', 'title': 'Trattorie'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': -33.45072, 'longitude': -70.623966},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': 'Av. Italia 1791',
#     'address2': None,
#     'address3': None,
#     'city': 'Santiago',
#     'zip_code': '7750000',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['Av. Italia 1791', 'RM 7750000 Santiago', 'Chile']},
#    'phone': '+5622742001',
#    'display_phone': '+56 22742001',
#    'distance': 766.8480925677007},
#   {'id': 'sK0uAwUhsFII6MkuyiMCFA',
#    'alias': 'la-cabrera-santiago',
#    'name': 'La Cabrera',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/cwJ0m5Iy4kM9hOEVMfwytA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-cabrera-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 7,
#    'categories': [{'alias': 'steak', 'title': 'Steakhouses'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': -33.40349, 'longitude': -70.58857},
#    'transactions': [],
#    'location': {'address1': 'Alonso de Córdova 4263',
#     'address2': '',
#     'address3': None,
#     'city': 'Santiago',
#     'zip_code': '',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['Alonso de Córdova 4263', 'RM Santiago', 'Chile']},
#    'phone': '+56932361687',
#    'display_phone': '+56 9 3236 1687',
#    'distance': 5653.6296605319685},
#   {'id': 'UV24IsNtNyM6_CQ84gJjOQ',
#    'alias': 'happening-santiago',
#    'name': 'Happening',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/jGWs5ZlgspCix8BXkVZWlA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/happening-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 22,
#    'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#     {'alias': 'argentine', 'title': 'Argentine'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': -33.4163155225805,
#     'longitude': -70.5954595103857},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': 'Av. Apoquindo 3090',
#     'address2': None,
#     'address3': None,
#     'city': 'Santiago',
#     'zip_code': '7550000',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['Av. Apoquindo 3090', 'RM 7550000 Santiago', 'Chile']},
#    'phone': '+56223621092',
#    'display_phone': '+56 2 2362 1092',
#    'distance': 4159.613851058186},
#   {'id': 'ixOo17AUmm0g6mishr44Qw',
#    'alias': 'estro-las-condes',
#    'name': 'Estro',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/JDNdxJw7YHiKT3urCHAjoQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/estro-las-condes?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 8,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'chilean', 'title': 'Chilean'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': -33.415755, 'longitude': -70.595348},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': 'El Alcalde 15',
#     'address2': '',
#     'address3': None,
#     'city': 'Las Condes',
#     'zip_code': '',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['El Alcalde 15', 'RM Las Condes', 'Chile']},
#    'phone': '+56224708585',
#    'display_phone': '+56 2 2470 8585',
#    'distance': 4212.801363574398},
#   {'id': 'Lukol5kg93RhRD0CVUBLhA',
#    'alias': 'el-ciudadano-santiago',
#    'name': 'El Ciudadano',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/3UzZ1S-Xs_IYxk0RG2UHug/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-ciudadano-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 24,
#    'categories': [{'alias': 'brasseries', 'title': 'Brasseries'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': -33.446033525825,
#     'longitude': -70.628685655542},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': 'Seminario 400',
#     'address2': '',
#     'address3': '',
#     'city': 'Santiago',
#     'zip_code': '7500847',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['Seminario 400', 'RM 7500847 Santiago', 'Chile']},
#    'phone': '+56222489548',
#    'display_phone': '+56 2 2248 9548',
#    'distance': 363.595728923461},
#   {'id': 'tv6JEnPx7rna8zdmZRA2hA',
#    'alias': 'lusitano-santiago',
#    'name': 'Lusitano',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/P3exK64LzSK8cto0y8-kqQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lusitano-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 20,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'portuguese', 'title': 'Portuguese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': -33.4476794, 'longitude': -70.6255941},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': 'Condell 1414',
#     'address2': '',
#     'address3': '',
#     'city': 'Santiago',
#     'zip_code': '7501463',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['Condell 1414', 'RM 7501463 Santiago', 'Chile']},
#    'phone': '+56997101381',
#    'display_phone': '+56 9 9710 1381',
#    'distance': 412.7354980081998},
#   {'id': 'uQ5yMmNe6geJVmMY_grMHQ',
#    'alias': 'le-due-torri-santiago-2',
#    'name': 'Le Due Torri',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/J7OILqLObSIb_rp4G2EFFg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-due-torri-santiago-2?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 7,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': -33.44009304923,
#     'longitude': -70.6481483430217},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': 'San Antonio 258',
#     'address2': '',
#     'address3': None,
#     'city': 'Santiago',
#     'zip_code': '8320000',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['San Antonio 258', 'RM 8320000 Santiago', 'Chile']},
#    'phone': '+56226333799',
#    'display_phone': '+56 2 2633 3799',
#    'distance': 2131.7233313692177},
#   {'id': 'b5duAmqZb0KsiXn2beMlyw',
#    'alias': 'the-white-rabbit-santiago',
#    'name': 'The White Rabbit',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/DPdk4s6YkSUJBqWCu8GsZQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-white-rabbit-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 32,
#    'categories': [{'alias': 'brasseries', 'title': 'Brasseries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': -33.4319495609575,
#     'longitude': -70.6344900195435},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': 'Antonia López de Bello 118',
#     'address2': '',
#     'address3': '',
#     'city': 'Santiago',
#     'zip_code': '7520288',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['Antonia López de Bello 118',
#      'RM 7520288 Santiago',
#      'Chile']},
#    'phone': '+56225034246',
#    'display_phone': '+56 2 2503 4246',
#    'distance': 1568.1371277466724},
#   {'id': 'ijrJ5Dcj-QEsOkYLN4BRbw',
#    'alias': 'mr-hans-chicken-santiago',
#    'name': "Mr Han's Chicken",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/dgCeEybAAmvLtm--2momlw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mr-hans-chicken-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 1,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': -33.431665457678,
#     'longitude': -70.6430004537106},
#    'transactions': [],
#    'location': {'address1': 'Antonia López de Bello 267',
#     'address2': '',
#     'address3': None,
#     'city': 'Santiago',
#     'zip_code': '',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['Antonia López de Bello 267', 'RM Santiago', 'Chile']},
#    'phone': '+56222138913',
#    'display_phone': '+56 2 2213 8913',
#    'distance': 2112.7984614121137},
#   {'id': 'gYWe5Uy7cfzEgLxshGW1AA',
#    'alias': 'el-mesón-de-la-patagonia-santiago',
#    'name': 'El Mesón de La Patagonia',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/i7sCLk-h8jUVMdtAD-QveA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-mes%C3%B3n-de-la-patagonia-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 7,
#    'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#     {'alias': 'chilean', 'title': 'Chilean'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': -33.35749171734,
#     'longitude': -70.5065664183076},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': 'Av. Lo Barnechea 1223',
#     'address2': None,
#     'address3': None,
#     'city': 'Santiago',
#     'zip_code': '7690000',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['Av. Lo Barnechea 1223',
#      'RM 7690000 Santiago',
#      'Chile']},
#    'phone': '+5622168967',
#    'display_phone': '+56 22168967',
#    'distance': 14651.267173112768},
#   {'id': 'x_DdLWauj4tkkjapr8xFrQ',
#    'alias': 'naoki-santiago',
#    'name': 'Naoki',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/PsKDcu2T9l2Ttui1mYE7mg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/naoki-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 23,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': -33.4005887, 'longitude': -70.5924643},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': 'Vitacura 3875',
#     'address2': '',
#     'address3': '',
#     'city': 'Santiago',
#     'zip_code': '7630000',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['Vitacura 3875', 'RM 7630000 Santiago', 'Chile']},
#    'phone': '+56222075291',
#    'display_phone': '+56 2 2207 5291',
#    'distance': 5722.833065755695},
#   {'id': '8dkDcJ_jAc4RPBqmmYKwXA',
#    'alias': 'dae-jang-kum-santiago',
#    'name': 'Dae Jang Kum',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/yipMhQY5RBvJctP4OMJjcQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dae-jang-kum-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 9,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'korean', 'title': 'Korean'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': -33.4318428, 'longitude': -70.6399002},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': 'Bombero Núñez 174',
#     'address2': '',
#     'address3': '',
#     'city': 'Santiago',
#     'zip_code': '8420000',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['Bombero Núñez 174', 'RM 8420000 Santiago', 'Chile']},
#    'phone': '+56227324772',
#    'display_phone': '+56 2 2732 4772',
#    'distance': 1888.5734728640355},
#   {'id': '7fUOuXtQBsskDnza60AXAw',
#    'alias': 'ootoya-santiago',
#    'name': 'Ootoya',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/31KXjhS9Htkaf-ONEuwk1w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ootoya-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 4,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'panasian', 'title': 'Pan Asian'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': -33.432904, 'longitude': -70.634749},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': 'Constitución 125',
#     'address2': '',
#     'address3': '',
#     'city': 'Santiago',
#     'zip_code': '7520360',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['Constitución 125', 'RM 7520360 Santiago', 'Chile']},
#    'phone': '+56981456978',
#    'display_phone': '+56 9 8145 6978',
#    'distance': 1492.201559710997},
#   {'id': 'e33bsBHIZAH8RMOh0Z4HRQ',
#    'alias': 'el-hoyo-santiago',
#    'name': 'El Hoyo',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/M5pZm5d6CbIMdyftckFRkw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/el-hoyo-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 9,
#    'categories': [{'alias': 'chilean', 'title': 'Chilean'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': -33.4553319270182,
#     'longitude': -70.6775925843539},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': 'San Vicente 375',
#     'address2': None,
#     'address3': None,
#     'city': 'Santiago',
#     'zip_code': None,
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['San Vicente 375', 'RM Santiago', 'Chile']},
#    'phone': '+56226890339',
#    'display_phone': '+56 2 2689 0339',
#    'distance': 4982.2205293082425},
#   {'id': '00L35I2hHo7cMEZNtOx08Q',
#    'alias': 'peztoro-santiago',
#    'name': 'Peztoro',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-0keAJTSCTr3RPjvHeo2uQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/peztoro-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 20,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'latin', 'title': 'Latin American'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': -33.4389341427613,
#     'longitude': -70.6412808224559},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': 'José Victorino Lastarria 70',
#     'address2': '',
#     'address3': '',
#     'city': 'Santiago',
#     'zip_code': '8320000',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['José Victorino Lastarria 70',
#      'RM 8320000 Santiago',
#      'Chile']},
#    'phone': '+5626646411',
#    'display_phone': '+56 26646411',
#    'distance': 1554.7739516652418},
#   {'id': 'oZ_pVyyyGS8mghqZ9X_NUw',
#    'alias': 'baco-santiago',
#    'name': 'Baco',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/BoXNPNcXFn4BFBO_3uU9sw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/baco-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 70,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': -33.42095352, 'longitude': -70.61044579},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': 'Nueva de Lyon 113',
#     'address2': None,
#     'address3': None,
#     'city': 'Santiago',
#     'zip_code': None,
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['Nueva de Lyon 113', 'RM Santiago', 'Chile']},
#    'phone': '+56222314444',
#    'display_phone': '+56 2 2231 4444',
#    'distance': 2922.140387306437},
#   {'id': 'bnVMPaCGPu_EwtG4FdIjrw',
#    'alias': 'caminito-restaurant-santiago',
#    'name': 'Caminito Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/newQG26XaXdXdjthNWT4-Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/caminito-restaurant-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 1,
#    'categories': [{'alias': 'argentine', 'title': 'Argentine'},
#     {'alias': 'steak', 'title': 'Steakhouses'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': -33.4427965011663,
#     'longitude': -70.5941757314229},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': 'El Aguilucho 3555',
#     'address2': None,
#     'address3': None,
#     'city': 'Santiago',
#     'zip_code': '7500000',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['El Aguilucho 3555', 'RM 7500000 Santiago', 'Chile']},
#    'phone': '+5622090526',
#    'display_phone': '+56 22090526',
#    'distance': 2923.023104724819},
#   {'id': '2K3dN-x3HovH1d_MPh9NIw',
#    'alias': 'in-pasta-santiago',
#    'name': 'In Pasta',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/8L2df_NrUcxM52bA5UGeVg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/in-pasta-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 6,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': -33.4466879406616,
#     'longitude': -70.626129307522},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': 'Sta. Isabel 0395',
#     'address2': '',
#     'address3': '',
#     'city': 'Santiago',
#     'zip_code': '8150000',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['Sta. Isabel 0395', 'RM 8150000 Santiago', 'Chile']},
#    'phone': '+56226347575',
#    'display_phone': '+56 2 2634 7575',
#    'distance': 305.74133019159405},
#   {'id': 'UECycuZX-G9RRo5jEQ_KPA',
#    'alias': 'pinpilinpausha-santiago',
#    'name': 'Pinpilinpausha',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/N-sQFl3sW1RGPKOXj3jNZw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pinpilinpausha-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 19,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': -33.413753, 'longitude': -70.601836},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': 'Isidora Goyenechea 2900',
#     'address2': None,
#     'address3': None,
#     'city': 'Santiago',
#     'zip_code': '',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['Isidora Goyenechea 2900', 'RM Santiago', 'Chile']},
#    'phone': '+56232754303',
#    'display_phone': '+56 2 3275 4303',
#    'distance': 4021.2867463074112},
#   {'id': 'uBP5ISVSd5D0eEJTgLtmnQ',
#    'alias': 'marisquería-clarita-santiago',
#    'name': 'Marisquería Clarita',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6o2WCnihlcZHdHutbIyJ9Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/marisquer%C3%ADa-clarita-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 6,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': -33.4343338, 'longitude': -70.651474},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': 'San Pablo 1000',
#     'address2': 'Loc. 97',
#     'address3': None,
#     'city': 'Santiago',
#     'zip_code': '',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['San Pablo 1000', 'Loc. 97', 'RM Santiago', 'Chile']},
#    'phone': '+5626873975',
#    'display_phone': '+56 26873975',
#    'distance': 2646.6116786612756},
#   {'id': '09XfKLTkHeukEBknM8B_dA',
#    'alias': 'madam-tusan-santiago',
#    'name': 'Madam Tusan',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/LqxfqSiR0PUVwbnPEW6Oog/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/madam-tusan-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 15,
#    'categories': [{'alias': 'peruvian', 'title': 'Peruvian'},
#     {'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': -33.4177821691224,
#     'longitude': -70.6062082165749},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': 'Av. Andrés Bello 2447',
#     'address2': '',
#     'address3': '',
#     'city': 'Santiago',
#     'zip_code': '7550000',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['Av. Andrés Bello 2447',
#      'RM 7550000 Santiago',
#      'Chile']},
#    'phone': '+56226189752',
#    'display_phone': '+56 2 2618 9752',
#    'distance': 3425.2459804299624},
#   {'id': '8QxhbyN-9F_3I1ES_R5DoA',
#    'alias': 'las-vacas-gordas-santiago',
#    'name': 'Las Vacas Gordas',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/xiRPu1ieK-i3yO0u6Kxt9g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/las-vacas-gordas-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 15,
#    'categories': [{'alias': 'steak', 'title': 'Steakhouses'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': -33.4411554711322,
#     'longitude': -70.663706055986},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': 'Cienfuegos 280',
#     'address2': None,
#     'address3': None,
#     'city': 'Santiago',
#     'zip_code': '8320000',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['Cienfuegos 280', 'RM 8320000 Santiago', 'Chile']},
#    'phone': '+56226971066',
#    'display_phone': '+56 2 2697 1066',
#    'distance': 3545.0610447809},
#   {'id': '8XAW5okaLleJD3FYTZnscw',
#    'alias': 'ramen-kintaro-santiago',
#    'name': 'Ramen Kintaro',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/yvW-Gd_o2yWZsCG1EcY-ZA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ramen-kintaro-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 8,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': -33.4366925238364,
#     'longitude': -70.6440740078688},
#    'transactions': [],
#    'location': {'address1': 'Monjitas 460',
#     'address2': '',
#     'address3': None,
#     'city': 'Santiago',
#     'zip_code': '',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['Monjitas 460', 'RM Santiago', 'Chile']},
#    'phone': '+56226382448',
#    'display_phone': '+56 2 2638 2448',
#    'distance': 1891.4518059278432},
#   {'id': 'p5jngo0JYcNguv7upJwPwQ',
#    'alias': 'boragó-santiago',
#    'name': 'Boragó',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/OYDT4xQl3CewasEartvniA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/borag%C3%B3-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 25,
#    'categories': [{'alias': 'chilean', 'title': 'Chilean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': -33.3824440981482,
#     'longitude': -70.5839843853195},
#    'transactions': [],
#    'location': {'address1': 'Av San Josemaría Escrivá de Balaguer 5970',
#     'address2': '',
#     'address3': None,
#     'city': 'Santiago',
#     'zip_code': '',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['Av San Josemaría Escrivá de Balaguer 5970',
#      'RM Santiago',
#      'Chile']},
#    'phone': '+56229538893',
#    'display_phone': '+56 2 2953 8893',
#    'distance': 7858.441378913182},
#   {'id': 'T6ENSUv8tDALgdBPdsTPWw',
#    'alias': 'miraolas-santiago-2',
#    'name': 'Miraolas',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/eoh6zLdN706psGJdnUMJ1A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/miraolas-santiago-2?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 13,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': -33.39974101, 'longitude': -70.59008077},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': 'Av. Vitacura 4171',
#     'address2': None,
#     'address3': None,
#     'city': 'Santiago',
#     'zip_code': '7630000',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['Av. Vitacura 4171', 'RM 7630000 Santiago', 'Chile']},
#    'phone': '+56222060202',
#    'display_phone': '+56 2 2206 0202',
#    'distance': 5922.884061292359},
#   {'id': 'iwDQhmGylgrDbp8gXeMtJw',
#    'alias': 'da-dino-santiago-2',
#    'name': 'Da-Dino',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/PhyuOjZwQXEZpDn6dhBBow/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/da-dino-santiago-2?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 5,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': -33.44195442, 'longitude': -70.6462221},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': "Av. Libertador Bernardo O'Higgins 737",
#     'address2': None,
#     'address3': None,
#     'city': 'Santiago',
#     'zip_code': '8320000',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ["Av. Libertador Bernardo O'Higgins 737",
#      'RM 8320000 Santiago',
#      'Chile']},
#    'phone': '+5626381833',
#    'display_phone': '+56 26381833',
#    'distance': 1922.0625269183597},
#   {'id': 'FcQ0WD5LiJTxCZ0kGH2yww',
#    'alias': 'silvestre-bistró-santiago',
#    'name': 'Silvestre Bistró',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/n30v34WxuSs6vAIvwzD37Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/silvestre-bistr%C3%B3-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 14,
#    'categories': [{'alias': 'signature_cuisine',
#      'title': 'Signature Cuisine'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': -33.448243, 'longitude': -70.6236202},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': 'Caupolicán 511',
#     'address2': '',
#     'address3': '',
#     'city': 'Santiago',
#     'zip_code': '',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['Caupolicán 511', 'RM Santiago', 'Chile']},
#    'phone': '+56991569974',
#    'display_phone': '+56 9 9156 9974',
#    'distance': 511.2466070857914},
#   {'id': 'E57pMqeAUdogI1Y8D9alcw',
#    'alias': 'restaurant-vegetariano-soju-santiago',
#    'name': 'Restaurant Vegetariano Soju',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/eLkjk8eIGCXUX1z4KkWASA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/restaurant-vegetariano-soju-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 13,
#    'categories': [{'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'vegetarian', 'title': 'Vegetarian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': -33.4380810113056,
#     'longitude': -70.648650560852},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': 'Galería Santiago',
#     'address2': 'Merced 821',
#     'address3': 'Local 17',
#     'city': 'Santiago',
#     'zip_code': '8320000',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['Galería Santiago',
#      'Merced 821',
#      'Local 17',
#      'RM 8320000 Santiago',
#      'Chile']},
#    'phone': '+56226895764',
#    'display_phone': '+56 2 2689 5764',
#    'distance': 2232.473144878206},
#   {'id': 'ru9I6hxoA3HqkkZpZ0p5UQ',
#    'alias': 'new-horizon-santiago-2',
#    'name': 'New Horizon',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/6MNsiI9_3FQHORctlleodA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/new-horizon-santiago-2?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#    'review_count': 28,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': -33.437766, 'longitude': -70.64511},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': 'Merced 565',
#     'address2': '',
#     'address3': '',
#     'city': 'Santiago',
#     'zip_code': '8320000',
#     'country': 'CL',
#     'state': 'RM',
#     'display_address': ['Merced 565', 'RM 8320000 Santiago', 'Chile']},
#    'phone': '+56226323622',
#    'display_phone': '+56 2 2632 3622',
#    'distance': 1933.0318733238532}],
#  'total': 2200,
#  'region': {'center': {'longitude': -70.6256103515625,
#    'latitude': -33.44387694471913}}}

# %%
#Veamos los keys del diccionario recibido
data.keys() #el key 'businesses' contiene la información que nos interesa
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
#El primer elemento del diccionario indica el total de restaurants existentes en la API
print('En total la base de datos registra %d restaurants'%data['total'])
# Out:
# En total la base de datos registra 2200 restaurants

# %%
data['businesses'] # el segundo elemento del diccionario es una lista de diccionarios, donde cada diccionario corresponde a un restaurant en particular
# Out:
# [{'id': '8N6Y3HsLXHBeFwhlO0YxwQ',
#   'alias': 'barrica-94-santiago',
#   'name': 'Barrica 94',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/QXbJCQglsDKGTaCOkmcvIA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/barrica-94-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 77,
#   'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#    {'alias': 'chilean', 'title': 'Chilean'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': -33.4342880070125,
#    'longitude': -70.6352240592241},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': 'Bellavista 052',
#    'address2': '',
#    'address3': '',
#    'city': 'Santiago',
#    'zip_code': '8320000',
#    'country': 'CL',
#    'state': 'RM',
#    'display_address': ['Bellavista 052', 'RM 8320000 Santiago', 'Chile']},
#   'phone': '+5627324939',
#   'display_phone': '+56 27324939',
#   'distance': 1395.7350189410245},
#  {'id': 'y2FR-JBGie4wiW6RjtKLhg',
#   'alias': 'aquí-está-coco-santiago',
#   'name': 'Aquí Está Coco',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/W9lFJpoTKj4xXVjw_hQY9A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/aqu%C3%AD-est%C3%A1-coco-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 57,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': -33.42406349, 'longitude': -70.61662393},
#   'transactions': [],
#   'price': '$$$$',
#   'location': {'address1': 'La Concepción 236',
#    'address2': None,
#    'address3': None,
#    'city': 'Santiago',
#    'zip_code': None,
#    'country': 'CL',
#    'state': 'RM',
#    'display_address': ['La Concepción 236', 'RM Santiago', 'Chile']},
#   'phone': '+5624106200',
#   'display_phone': '+56 24106200',
#   'distance': 2366.370671235577},
#  {'id': 'U15KdCy6HH05WISNtN9plQ',
#   'alias': 'restaurant-peumayén-santiago',
#   'name': 'Restaurant Peumayén',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/wkJAtF3Z4X5FUw5CR4c7tg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/restaurant-peumay%C3%A9n-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 71,
#   'categories': [{'alias': 'latin', 'title': 'Latin American'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': -33.4328073, 'longitude': -70.6348213},
#   'transactions': [],
#   'price': '$$$$',
#   'location': {'address1': 'Constitución 136',
#    'address2': '',
#    'address3': '',
#    'city': 'Santiago',
#    'zip_code': '7500000',
#    'country': 'CL',
#    'state': 'RM',
#    'display_address': ['Constitución 136', 'RM 7500000 Santiago', 'Chile']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 1504.863539969912},
#  {'id': 'LGwEqYL0reUsRdtqE44ITQ',
#   'alias': 'chipe-libre-república-independiente-del-pisco-santiago-2',
#   'name': 'Chipe Libre - República Independiente del Pisco',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/poKwCUHwy7ThWSbBTSOAFA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/chipe-libre-rep%C3%BAblica-independiente-del-pisco-santiago-2?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 73,
#   'categories': [{'alias': 'bars', 'title': 'Bars'},
#    {'alias': 'peruvian', 'title': 'Peruvian'},
#    {'alias': 'chilean', 'title': 'Chilean'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': -33.4383392, 'longitude': -70.6411438},
#   'transactions': [],
#   'price': '$$$',
#   'location': {'address1': 'José Victorino Lastarria 282',
#    'address2': '',
#    'address3': '',
#    'city': 'Santiago',
#    'zip_code': '8320156',
#    'country': 'CL',
#    'state': 'RM',
#    'display_address': ['José Victorino Lastarria 282',
#     'RM 8320156 Santiago',
#     'Chile']},
#   'phone': '+56226640584',
#   'display_phone': '+56 2 2664 0584',
#   'distance': 1568.1348862352445},
#  {'id': 'kEJ3b72MKnXtTGEGqXOy7w',
#   'alias': 'confitería-torres-santiago-2',
#   'name': 'Confitería Torres',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/CnBmm2eIdZAq4q8GHcmefQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/confiter%C3%ADa-torres-santiago-2?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 27,
#   'categories': [{'alias': 'chilean', 'title': 'Chilean'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': -33.4141366, 'longitude': -70.5998601},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': 'Isidora Goyenechea 2962',
#    'address2': '',
#    'address3': '',
#    'city': 'Santiago',
#    'zip_code': '7550000',
#    'country': 'CL',
#    'state': 'RM',
#    'display_address': ['Isidora Goyenechea 2962',
#     'RM 7550000 Santiago',
#     'Chile']},
#   'phone': '+56223332639',
#   'display_phone': '+56 2 2333 2639',
#   'distance': 4090.222251189459},
#  {'id': 'D7aZ9ZGpnyObEawvMsXi_A',
#   'alias': 'liguria-santiago-5',
#   'name': 'Liguria',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/5ANiJhZDUqkF0F_htgLtnA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/liguria-santiago-5?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 29,
#   'categories': [{'alias': 'chilean', 'title': 'Chilean'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': -33.418295, 'longitude': -70.6028055},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': 'Luis Thayer Ojeda 019',
#    'address2': None,
#    'address3': None,
#    'city': 'Santiago',
#    'zip_code': '7500000',
#    'country': 'CL',
#    'state': 'RM',
#    'display_address': ['Luis Thayer Ojeda 019',
#     'RM 7500000 Santiago',
#     'Chile']},
#   'phone': '+56222311393',
#   'display_phone': '+56 2 2231 1393',
#   'distance': 3555.6174257192474},
#  {'id': 'KQ2D3gs9y0wIuTqoKOHO4w',
#   'alias': 'mestizo-santiago',
#   'name': 'Mestizo',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/GV-sn6fGs1JteFYHxzHK6A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mestizo-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 56,
#   'categories': [{'alias': 'chilean', 'title': 'Chilean'},
#    {'alias': 'international', 'title': 'International'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': -33.394083457956, 'longitude': -70.600033248157},
#   'transactions': [],
#   'price': '$$$$',
#   'location': {'address1': 'Av. del Bicentenario 4050',
#    'address2': None,
#    'address3': None,
#    'city': 'Santiago',
#    'zip_code': '8320000',
#    'country': 'CL',
#    'state': 'RM',
#    'display_address': ['Av. del Bicentenario 4050',
#     'RM 8320000 Santiago',
#     'Chile']},
#   'phone': '+56974776093',
#   'display_phone': '+56 9 7477 6093',
#   'distance': 6034.856264954543},
#  {'id': 'ffHk4q3jDiMrTMLLU6kcIA',
#   'alias': 'tiramisú-santiago-2',
#   'name': 'Tiramisú',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-RWxoc49-13rEggEA-T8vQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/tiramis%C3%BA-santiago-2?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 100,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': -33.414562406985, 'longitude': -70.597506713488},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': 'Av. Isidora Goyenechea 3141',
#    'address2': None,
#    'address3': None,
#    'city': 'Santiago',
#    'zip_code': '7550000',
#    'country': 'CL',
#    'state': 'RM',
#    'display_address': ['Av. Isidora Goyenechea 3141',
#     'RM 7550000 Santiago',
#     'Chile']},
#   'phone': '+56225194900',
#   'display_phone': '+56 2 2519 4900',
#   'distance': 4184.612745348328},
#  {'id': 'CAFL80wAGOMcPrEO6uMnkA',
#   'alias': 'fuente-alemana-santiago-2',
#   'name': 'Fuente Alemana',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ybpl5_bbk0tbaFEAOxFRNw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/fuente-alemana-santiago-2?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 57,
#   'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': -33.4375198417072,
#    'longitude': -70.6360235448149},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': "Av. Libertador Bernardo O'Higgins 58",
#    'address2': None,
#    'address3': None,
#    'city': 'Santiago',
#    'zip_code': '8320000',
#    'country': 'CL',
#    'state': 'RM',
#    'display_address': ["Av. Libertador Bernardo O'Higgins 58",
#     'RM 8320000 Santiago',
#     'Chile']},
#   'phone': '+5626393231',
#   'display_phone': '+56 26393231',
#   'distance': 1200.383671071289},
#  {'id': 'Qtni8AS93H71AfyDIsijZg',
#   'alias': 'casaluz-santiago-4',
#   'name': 'Casaluz',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/54t0O8-f3lE3sSMzYfX6cw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/casaluz-santiago-4?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 26,
#   'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#    {'alias': 'bars', 'title': 'Bars'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': -33.442185, 'longitude': -70.626424},
#   'transactions': [],
#   'price': '$$$',
#   'location': {'address1': 'Av. Italia 805',
#    'address2': '',
#    'address3': '',
#    'city': 'Santiago',
#    'zip_code': '7501184',
#    'country': 'CL',
#    'state': 'RM',
#    'display_address': ['Av. Italia 805', 'RM 7501184 Santiago', 'Chile']},
#   'phone': '+56229187204',
#   'display_phone': '+56 2 2918 7204',
#   'distance': 210.91869264079745},
#  {'id': 'TmD9C8IRlvubHa-_AeK-wg',
#   'alias': 'california-cantina-santiago',
#   'name': 'California Cantina',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/7eXTRP2rDKDZd1VKkH5Hxw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/california-cantina-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 53,
#   'categories': [{'alias': 'sportsbars', 'title': 'Sports Bars'},
#    {'alias': 'mexican', 'title': 'Mexican'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': -33.42242, 'longitude': -70.611942},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': 'Las Urbinas 44',
#    'address2': '',
#    'address3': '',
#    'city': 'Santiago',
#    'zip_code': '7510105',
#    'country': 'CL',
#    'state': 'RM',
#    'display_address': ['Las Urbinas 44', 'RM 7510105 Santiago', 'Chile']},
#   'phone': '+56962493041',
#   'display_phone': '+56 9 6249 3041',
#   'distance': 2712.64205254666},
#  {'id': '9L7D68rsmWKp3ynU8xA4TQ',
#   'alias': 'la-mar-santiago',
#   'name': 'La Mar',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/tlsRecrJZzhcyPOxiPptrw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/la-mar-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 39,
#   'categories': [{'alias': 'peruvian', 'title': 'Peruvian'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': -33.3997243, 'longitude': -70.5909546},
#   'transactions': [],
#   'price': '$$$$',
#   'location': {'address1': 'Av. Nueva Costanera 4076',
#    'address2': '',
#    'address3': '',
#    'city': 'Santiago',
#    'zip_code': '7630000',
#    'country': 'CL',
#    'state': 'RM',
#    'display_address': ['Av. Nueva Costanera 4076',
#     'RM 7630000 Santiago',
#     'Chile']},
#   'phone': '+56222067839',
#   'display_phone': '+56 2 2206 7839',
#   'distance': 5879.6278181647995},
#  {'id': 'pIaTdO4k6MDcin_I4SF6ig',
#   'alias': 'biwon-santiago',
#   'name': 'Biwon',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/iLRzKIuvuigCTPQ2h2HGzg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/biwon-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 3,
#   'categories': [{'alias': 'korean', 'title': 'Korean'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': -33.4223375, 'longitude': -70.6053371},
#   'transactions': [],
#   'price': '$$$',
#   'location': {'address1': 'Coronel 2376',
#    'address2': 'Providencia',
#    'address3': '',
#    'city': 'Santiago',
#    'zip_code': '',
#    'country': 'CL',
#    'state': 'RM',
#    'display_address': ['Coronel 2376', 'Providencia', 'RM Santiago', 'Chile']},
#   'phone': '+56229518000',
#   'display_phone': '+56 2 2951 8000',
#   'distance': 3055.675313074462},
#  {'id': 'x4R6h8NqBQmEp-tAnyFO3g',
#   'alias': 'castillo-forestal-santiago',
#   'name': 'Castillo Forestal',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ToIFZdvL4LsQqx8s40u32w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/castillo-forestal-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 19,
#   'categories': [{'alias': 'french', 'title': 'French'},
#    {'alias': 'chilean', 'title': 'Chilean'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': -33.4348361156787,
#    'longitude': -70.642646313429},
#   'transactions': [],
#   'price': '$$$',
#   'location': {'address1': 'Av. Cardenal José María Caro 390',
#    'address2': '',
#    'address3': '',
#    'city': 'Santiago',
#    'zip_code': '8320000',
#    'country': 'CL',
#    'state': 'RM',
#    'display_address': ['Av. Cardenal José María Caro 390',
#     'RM 8320000 Santiago',
#     'Chile']},
#   'phone': '+56226641544',
#   'display_phone': '+56 2 2664 1544',
#   'distance': 1875.8476195894168},
#  {'id': 'IUBOvOYsrcyRMdp8V2O06g',
#   'alias': 'la-diana-santiago',
#   'name': 'La Diana',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/RDs9-jGAOXcwittq038xWQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/la-diana-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 13,
#   'categories': [{'alias': 'brasseries', 'title': 'Brasseries'},
#    {'alias': 'pubs', 'title': 'Pubs'},
#    {'alias': 'latin', 'title': 'Latin American'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': -33.450898, 'longitude': -70.649611},
#   'transactions': [],
#   'price': '$$$',
#   'location': {'address1': 'Arturo Prat 435',
#    'address2': '',
#    'address3': '',
#    'city': 'Santiago',
#    'zip_code': '8320000',
#    'country': 'CL',
#    'state': 'RM',
#    'display_address': ['Arturo Prat 435', 'RM 8320000 Santiago', 'Chile']},
#   'phone': '+56226649018',
#   'display_phone': '+56 2 2664 9018',
#   'distance': 2353.060860197377},
#  {'id': 'EG1MtnU1CapiqemCj9gPDg',
#   'alias': 'la-hacienda-gaucha-santiago-2',
#   'name': 'La Hacienda Gaucha',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/YiUIO9cx1MLEXR5WakCR_A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/la-hacienda-gaucha-santiago-2?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 13,
#   'categories': [{'alias': 'bbq', 'title': 'Barbeque'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': -33.4386931069913,
#    'longitude': -70.6081252589997},
#   'transactions': [],
#   'price': '$$$',
#   'location': {'address1': 'Pedro de Valdivia 1719',
#    'address2': '',
#    'address3': '',
#    'city': 'Santiago',
#    'zip_code': '7810000',
#    'country': 'CL',
#    'state': 'RM',
#    'display_address': ['Pedro de Valdivia 1719',
#     'RM 7810000 Santiago',
#     'Chile']},
#   'phone': '+5622235305',
#   'display_phone': '+56 22235305',
#   'distance': 1728.418689590485},
#  {'id': 'pCgqgk_aHrSrV-Hg0qjZfw',
#   'alias': 'karai-las-condes',
#   'name': 'Karai',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/fUBbyQKQNOmIPIwXN2NwZA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/karai-las-condes?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 14,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'peruvian', 'title': 'Peruvian'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': -33.41401, 'longitude': -70.598254},
#   'transactions': [],
#   'location': {'address1': 'Isidora Goyenechea 3000',
#    'address2': '',
#    'address3': None,
#    'city': 'Las Condes',
#    'zip_code': '',
#    'country': 'CL',
#    'state': 'RM',
#    'display_address': ['Isidora Goyenechea 3000', 'RM Las Condes', 'Chile']},
#   'phone': '+56227700081',
#   'display_phone': '+56 2 2770 0081',
#   'distance': 4190.356945819561},
#  {'id': 'FJcBzuQrcQkNWcfpcqcV3Q',
#   'alias': 'shinsei-vitacura',
#   'name': 'Shinsei',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/s49XqHx0hJ7r_mZkIM-22A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/shinsei-vitacura?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 3,
#   'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'nikkei', 'title': 'Nikkei'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': -33.40285, 'longitude': -70.58438},
#   'transactions': [],
#   'location': {'address1': 'Av. Presidente Kennedy 4700',
#    'address2': '',
#    'address3': None,
#    'city': 'Vitacura',
#    'zip_code': '',
#    'country': 'CL',
#    'state': 'RM',
#    'display_address': ['Av. Presidente Kennedy 4700', 'RM Vitacura', 'Chile']},
#   'phone': '+56226788864',
#   'display_phone': '+56 2 2678 8864',
#   'distance': 5985.2257868397355},
#  {'id': 'LyUwbW2c_0TpaYLp1tY0Gg',
#   'alias': 'el-camino-santiago',
#   'name': 'El Camino',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ZqtwXiubcFQUvhFO3jqLtg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/el-camino-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 12,
#   'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#    {'alias': 'bbq', 'title': 'Barbeque'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': -33.44413, 'longitude': -70.62555},
#   'transactions': [],
#   'price': '$$$',
#   'location': {'address1': 'Av. Italia 1034',
#    'address2': None,
#    'address3': '',
#    'city': 'Santiago',
#    'zip_code': '7501297',
#    'country': 'CL',
#    'state': 'RM',
#    'display_address': ['Av. Italia 1034', 'RM 7501297 Santiago', 'Chile']},
#   'phone': '+56229860765',
#   'display_phone': '+56 2 2986 0765',
#   'distance': 20.226421392849538},
#  {'id': 'lo8nbta9XAXYDmSNglDytA',
#   'alias': 'rishtedar-santiago',
#   'name': 'Rishtedar',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/0ZN05aQa9N6CcjkLy8ZdeQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/rishtedar-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 28,
#   'categories': [{'alias': 'indpak', 'title': 'Indian'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': -33.4206034617984,
#    'longitude': -70.6036070962787},
#   'transactions': [],
#   'price': '$$$',
#   'location': {'address1': 'Av. Holanda 160',
#    'address2': None,
#    'address3': None,
#    'city': 'Santiago',
#    'zip_code': '7500000',
#    'country': 'CL',
#    'state': 'RM',
#    'display_address': ['Av. Holanda 160', 'RM 7500000 Santiago', 'Chile']},
#   'phone': '+56222313257',
#   'display_phone': '+56 2 2231 3257',
#   'distance': 3306.4843940255814},
#  {'id': 'P0eaVPMLwFXK-RC8jB1RgQ',
#   'alias': 'liguria-santiago',
#   'name': 'Liguria',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/nCCeg-D47CdH5gBXPyjh9A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/liguria-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 20,
#   'categories': [{'alias': 'chilean', 'title': 'Chilean'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': -33.4230685659973,
#    'longitude': -70.6127871917753},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': 'Av. Pedro de Valdivia 47',
#    'address2': None,
#    'address3': None,
#    'city': 'Santiago',
#    'zip_code': '',
#    'country': 'CL',
#    'state': 'RM',
#    'display_address': ['Av. Pedro de Valdivia 47', 'RM Santiago', 'Chile']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 2612.4091994520086},
#  {'id': 'DUbB2zPmssqzUTdQGcWKvQ',
#   'alias': 'da-noi-santiago',
#   'name': 'Da Noi',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Gz3KYYF9ISTyshhp3QTsig/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/da-noi-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 14,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'trattorie', 'title': 'Trattorie'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': -33.45072, 'longitude': -70.623966},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': 'Av. Italia 1791',
#    'address2': None,
#    'address3': None,
#    'city': 'Santiago',
#    'zip_code': '7750000',
#    'country': 'CL',
#    'state': 'RM',
#    'display_address': ['Av. Italia 1791', 'RM 7750000 Santiago', 'Chile']},
#   'phone': '+5622742001',
#   'display_phone': '+56 22742001',
#   'distance': 766.8480925677007},
#  {'id': 'sK0uAwUhsFII6MkuyiMCFA',
#   'alias': 'la-cabrera-santiago',
#   'name': 'La Cabrera',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/cwJ0m5Iy4kM9hOEVMfwytA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/la-cabrera-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 7,
#   'categories': [{'alias': 'steak', 'title': 'Steakhouses'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': -33.40349, 'longitude': -70.58857},
#   'transactions': [],
#   'location': {'address1': 'Alonso de Córdova 4263',
#    'address2': '',
#    'address3': None,
#    'city': 'Santiago',
#    'zip_code': '',
#    'country': 'CL',
#    'state': 'RM',
#    'display_address': ['Alonso de Córdova 4263', 'RM Santiago', 'Chile']},
#   'phone': '+56932361687',
#   'display_phone': '+56 9 3236 1687',
#   'distance': 5653.6296605319685},
#  {'id': 'UV24IsNtNyM6_CQ84gJjOQ',
#   'alias': 'happening-santiago',
#   'name': 'Happening',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/jGWs5ZlgspCix8BXkVZWlA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/happening-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 22,
#   'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#    {'alias': 'argentine', 'title': 'Argentine'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': -33.4163155225805,
#    'longitude': -70.5954595103857},
#   'transactions': [],
#   'price': '$$$$',
#   'location': {'address1': 'Av. Apoquindo 3090',
#    'address2': None,
#    'address3': None,
#    'city': 'Santiago',
#    'zip_code': '7550000',
#    'country': 'CL',
#    'state': 'RM',
#    'display_address': ['Av. Apoquindo 3090', 'RM 7550000 Santiago', 'Chile']},
#   'phone': '+56223621092',
#   'display_phone': '+56 2 2362 1092',
#   'distance': 4159.613851058186},
#  {'id': 'ixOo17AUmm0g6mishr44Qw',
#   'alias': 'estro-las-condes',
#   'name': 'Estro',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/JDNdxJw7YHiKT3urCHAjoQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/estro-las-condes?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 8,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'chilean', 'title': 'Chilean'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': -33.415755, 'longitude': -70.595348},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': 'El Alcalde 15',
#    'address2': '',
#    'address3': None,
#    'city': 'Las Condes',
#    'zip_code': '',
#    'country': 'CL',
#    'state': 'RM',
#    'display_address': ['El Alcalde 15', 'RM Las Condes', 'Chile']},
#   'phone': '+56224708585',
#   'display_phone': '+56 2 2470 8585',
#   'distance': 4212.801363574398},
#  {'id': 'Lukol5kg93RhRD0CVUBLhA',
#   'alias': 'el-ciudadano-santiago',
#   'name': 'El Ciudadano',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/3UzZ1S-Xs_IYxk0RG2UHug/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/el-ciudadano-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 24,
#   'categories': [{'alias': 'brasseries', 'title': 'Brasseries'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': -33.446033525825, 'longitude': -70.628685655542},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': 'Seminario 400',
#    'address2': '',
#    'address3': '',
#    'city': 'Santiago',
#    'zip_code': '7500847',
#    'country': 'CL',
#    'state': 'RM',
#    'display_address': ['Seminario 400', 'RM 7500847 Santiago', 'Chile']},
#   'phone': '+56222489548',
#   'display_phone': '+56 2 2248 9548',
#   'distance': 363.595728923461},
#  {'id': 'tv6JEnPx7rna8zdmZRA2hA',
#   'alias': 'lusitano-santiago',
#   'name': 'Lusitano',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/P3exK64LzSK8cto0y8-kqQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/lusitano-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 20,
#   'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#    {'alias': 'portuguese', 'title': 'Portuguese'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': -33.4476794, 'longitude': -70.6255941},
#   'transactions': [],
#   'price': '$$$',
#   'location': {'address1': 'Condell 1414',
#    'address2': '',
#    'address3': '',
#    'city': 'Santiago',
#    'zip_code': '7501463',
#    'country': 'CL',
#    'state': 'RM',
#    'display_address': ['Condell 1414', 'RM 7501463 Santiago', 'Chile']},
#   'phone': '+56997101381',
#   'display_phone': '+56 9 9710 1381',
#   'distance': 412.7354980081998},
#  {'id': 'uQ5yMmNe6geJVmMY_grMHQ',
#   'alias': 'le-due-torri-santiago-2',
#   'name': 'Le Due Torri',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/J7OILqLObSIb_rp4G2EFFg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/le-due-torri-santiago-2?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 7,
#   'categories': [{'alias': 'italian', 'title': 'Italian'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': -33.44009304923, 'longitude': -70.6481483430217},
#   'transactions': [],
#   'price': '$$$',
#   'location': {'address1': 'San Antonio 258',
#    'address2': '',
#    'address3': None,
#    'city': 'Santiago',
#    'zip_code': '8320000',
#    'country': 'CL',
#    'state': 'RM',
#    'display_address': ['San Antonio 258', 'RM 8320000 Santiago', 'Chile']},
#   'phone': '+56226333799',
#   'display_phone': '+56 2 2633 3799',
#   'distance': 2131.7233313692177},
#  {'id': 'b5duAmqZb0KsiXn2beMlyw',
#   'alias': 'the-white-rabbit-santiago',
#   'name': 'The White Rabbit',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/DPdk4s6YkSUJBqWCu8GsZQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-white-rabbit-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 32,
#   'categories': [{'alias': 'brasseries', 'title': 'Brasseries'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': -33.4319495609575,
#    'longitude': -70.6344900195435},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': 'Antonia López de Bello 118',
#    'address2': '',
#    'address3': '',
#    'city': 'Santiago',
#    'zip_code': '7520288',
#    'country': 'CL',
#    'state': 'RM',
#    'display_address': ['Antonia López de Bello 118',
#     'RM 7520288 Santiago',
#     'Chile']},
#   'phone': '+56225034246',
#   'display_phone': '+56 2 2503 4246',
#   'distance': 1568.1371277466724},
#  {'id': 'ijrJ5Dcj-QEsOkYLN4BRbw',
#   'alias': 'mr-hans-chicken-santiago',
#   'name': "Mr Han's Chicken",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/dgCeEybAAmvLtm--2momlw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mr-hans-chicken-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 1,
#   'categories': [{'alias': 'korean', 'title': 'Korean'},
#    {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': -33.431665457678,
#    'longitude': -70.6430004537106},
#   'transactions': [],
#   'location': {'address1': 'Antonia López de Bello 267',
#    'address2': '',
#    'address3': None,
#    'city': 'Santiago',
#    'zip_code': '',
#    'country': 'CL',
#    'state': 'RM',
#    'display_address': ['Antonia López de Bello 267', 'RM Santiago', 'Chile']},
#   'phone': '+56222138913',
#   'display_phone': '+56 2 2213 8913',
#   'distance': 2112.7984614121137},
#  {'id': 'gYWe5Uy7cfzEgLxshGW1AA',
#   'alias': 'el-mesón-de-la-patagonia-santiago',
#   'name': 'El Mesón de La Patagonia',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/i7sCLk-h8jUVMdtAD-QveA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/el-mes%C3%B3n-de-la-patagonia-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 7,
#   'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#    {'alias': 'chilean', 'title': 'Chilean'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': -33.35749171734, 'longitude': -70.5065664183076},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': 'Av. Lo Barnechea 1223',
#    'address2': None,
#    'address3': None,
#    'city': 'Santiago',
#    'zip_code': '7690000',
#    'country': 'CL',
#    'state': 'RM',
#    'display_address': ['Av. Lo Barnechea 1223',
#     'RM 7690000 Santiago',
#     'Chile']},
#   'phone': '+5622168967',
#   'display_phone': '+56 22168967',
#   'distance': 14651.267173112768},
#  {'id': 'x_DdLWauj4tkkjapr8xFrQ',
#   'alias': 'naoki-santiago',
#   'name': 'Naoki',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/PsKDcu2T9l2Ttui1mYE7mg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/naoki-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 23,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': -33.4005887, 'longitude': -70.5924643},
#   'transactions': [],
#   'price': '$$$$',
#   'location': {'address1': 'Vitacura 3875',
#    'address2': '',
#    'address3': '',
#    'city': 'Santiago',
#    'zip_code': '7630000',
#    'country': 'CL',
#    'state': 'RM',
#    'display_address': ['Vitacura 3875', 'RM 7630000 Santiago', 'Chile']},
#   'phone': '+56222075291',
#   'display_phone': '+56 2 2207 5291',
#   'distance': 5722.833065755695},
#  {'id': '8dkDcJ_jAc4RPBqmmYKwXA',
#   'alias': 'dae-jang-kum-santiago',
#   'name': 'Dae Jang Kum',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/yipMhQY5RBvJctP4OMJjcQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/dae-jang-kum-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 9,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'korean', 'title': 'Korean'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': -33.4318428, 'longitude': -70.6399002},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': 'Bombero Núñez 174',
#    'address2': '',
#    'address3': '',
#    'city': 'Santiago',
#    'zip_code': '8420000',
#    'country': 'CL',
#    'state': 'RM',
#    'display_address': ['Bombero Núñez 174', 'RM 8420000 Santiago', 'Chile']},
#   'phone': '+56227324772',
#   'display_phone': '+56 2 2732 4772',
#   'distance': 1888.5734728640355},
#  {'id': '7fUOuXtQBsskDnza60AXAw',
#   'alias': 'ootoya-santiago',
#   'name': 'Ootoya',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/31KXjhS9Htkaf-ONEuwk1w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/ootoya-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 4,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'panasian', 'title': 'Pan Asian'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': -33.432904, 'longitude': -70.634749},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': 'Constitución 125',
#    'address2': '',
#    'address3': '',
#    'city': 'Santiago',
#    'zip_code': '7520360',
#    'country': 'CL',
#    'state': 'RM',
#    'display_address': ['Constitución 125', 'RM 7520360 Santiago', 'Chile']},
#   'phone': '+56981456978',
#   'display_phone': '+56 9 8145 6978',
#   'distance': 1492.201559710997},
#  {'id': 'e33bsBHIZAH8RMOh0Z4HRQ',
#   'alias': 'el-hoyo-santiago',
#   'name': 'El Hoyo',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/M5pZm5d6CbIMdyftckFRkw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/el-hoyo-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 9,
#   'categories': [{'alias': 'chilean', 'title': 'Chilean'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': -33.4553319270182,
#    'longitude': -70.6775925843539},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': 'San Vicente 375',
#    'address2': None,
#    'address3': None,
#    'city': 'Santiago',
#    'zip_code': None,
#    'country': 'CL',
#    'state': 'RM',
#    'display_address': ['San Vicente 375', 'RM Santiago', 'Chile']},
#   'phone': '+56226890339',
#   'display_phone': '+56 2 2689 0339',
#   'distance': 4982.2205293082425},
#  {'id': '00L35I2hHo7cMEZNtOx08Q',
#   'alias': 'peztoro-santiago',
#   'name': 'Peztoro',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-0keAJTSCTr3RPjvHeo2uQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/peztoro-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 20,
#   'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#    {'alias': 'latin', 'title': 'Latin American'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': -33.4389341427613,
#    'longitude': -70.6412808224559},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': 'José Victorino Lastarria 70',
#    'address2': '',
#    'address3': '',
#    'city': 'Santiago',
#    'zip_code': '8320000',
#    'country': 'CL',
#    'state': 'RM',
#    'display_address': ['José Victorino Lastarria 70',
#     'RM 8320000 Santiago',
#     'Chile']},
#   'phone': '+5626646411',
#   'display_phone': '+56 26646411',
#   'distance': 1554.7739516652418},
#  {'id': 'oZ_pVyyyGS8mghqZ9X_NUw',
#   'alias': 'baco-santiago',
#   'name': 'Baco',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/BoXNPNcXFn4BFBO_3uU9sw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/baco-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 70,
#   'categories': [{'alias': 'french', 'title': 'French'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': -33.42095352, 'longitude': -70.61044579},
#   'transactions': [],
#   'price': '$$$',
#   'location': {'address1': 'Nueva de Lyon 113',
#    'address2': None,
#    'address3': None,
#    'city': 'Santiago',
#    'zip_code': None,
#    'country': 'CL',
#    'state': 'RM',
#    'display_address': ['Nueva de Lyon 113', 'RM Santiago', 'Chile']},
#   'phone': '+56222314444',
#   'display_phone': '+56 2 2231 4444',
#   'distance': 2922.140387306437},
#  {'id': 'bnVMPaCGPu_EwtG4FdIjrw',
#   'alias': 'caminito-restaurant-santiago',
#   'name': 'Caminito Restaurant',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/newQG26XaXdXdjthNWT4-Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/caminito-restaurant-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 1,
#   'categories': [{'alias': 'argentine', 'title': 'Argentine'},
#    {'alias': 'steak', 'title': 'Steakhouses'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': -33.4427965011663,
#    'longitude': -70.5941757314229},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': 'El Aguilucho 3555',
#    'address2': None,
#    'address3': None,
#    'city': 'Santiago',
#    'zip_code': '7500000',
#    'country': 'CL',
#    'state': 'RM',
#    'display_address': ['El Aguilucho 3555', 'RM 7500000 Santiago', 'Chile']},
#   'phone': '+5622090526',
#   'display_phone': '+56 22090526',
#   'distance': 2923.023104724819},
#  {'id': '2K3dN-x3HovH1d_MPh9NIw',
#   'alias': 'in-pasta-santiago',
#   'name': 'In Pasta',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/8L2df_NrUcxM52bA5UGeVg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/in-pasta-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 6,
#   'categories': [{'alias': 'italian', 'title': 'Italian'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': -33.4466879406616,
#    'longitude': -70.626129307522},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': 'Sta. Isabel 0395',
#    'address2': '',
#    'address3': '',
#    'city': 'Santiago',
#    'zip_code': '8150000',
#    'country': 'CL',
#    'state': 'RM',
#    'display_address': ['Sta. Isabel 0395', 'RM 8150000 Santiago', 'Chile']},
#   'phone': '+56226347575',
#   'display_phone': '+56 2 2634 7575',
#   'distance': 305.74133019159405},
#  {'id': 'UECycuZX-G9RRo5jEQ_KPA',
#   'alias': 'pinpilinpausha-santiago',
#   'name': 'Pinpilinpausha',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/N-sQFl3sW1RGPKOXj3jNZw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/pinpilinpausha-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 19,
#   'categories': [{'alias': 'spanish', 'title': 'Spanish'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': -33.413753, 'longitude': -70.601836},
#   'transactions': [],
#   'price': '$$$$',
#   'location': {'address1': 'Isidora Goyenechea 2900',
#    'address2': None,
#    'address3': None,
#    'city': 'Santiago',
#    'zip_code': '',
#    'country': 'CL',
#    'state': 'RM',
#    'display_address': ['Isidora Goyenechea 2900', 'RM Santiago', 'Chile']},
#   'phone': '+56232754303',
#   'display_phone': '+56 2 3275 4303',
#   'distance': 4021.2867463074112},
#  {'id': 'uBP5ISVSd5D0eEJTgLtmnQ',
#   'alias': 'marisquería-clarita-santiago',
#   'name': 'Marisquería Clarita',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6o2WCnihlcZHdHutbIyJ9Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/marisquer%C3%ADa-clarita-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 6,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': -33.4343338, 'longitude': -70.651474},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': 'San Pablo 1000',
#    'address2': 'Loc. 97',
#    'address3': None,
#    'city': 'Santiago',
#    'zip_code': '',
#    'country': 'CL',
#    'state': 'RM',
#    'display_address': ['San Pablo 1000', 'Loc. 97', 'RM Santiago', 'Chile']},
#   'phone': '+5626873975',
#   'display_phone': '+56 26873975',
#   'distance': 2646.6116786612756},
#  {'id': '09XfKLTkHeukEBknM8B_dA',
#   'alias': 'madam-tusan-santiago',
#   'name': 'Madam Tusan',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/LqxfqSiR0PUVwbnPEW6Oog/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/madam-tusan-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 15,
#   'categories': [{'alias': 'peruvian', 'title': 'Peruvian'},
#    {'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': -33.4177821691224,
#    'longitude': -70.6062082165749},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': 'Av. Andrés Bello 2447',
#    'address2': '',
#    'address3': '',
#    'city': 'Santiago',
#    'zip_code': '7550000',
#    'country': 'CL',
#    'state': 'RM',
#    'display_address': ['Av. Andrés Bello 2447',
#     'RM 7550000 Santiago',
#     'Chile']},
#   'phone': '+56226189752',
#   'display_phone': '+56 2 2618 9752',
#   'distance': 3425.2459804299624},
#  {'id': '8QxhbyN-9F_3I1ES_R5DoA',
#   'alias': 'las-vacas-gordas-santiago',
#   'name': 'Las Vacas Gordas',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/xiRPu1ieK-i3yO0u6Kxt9g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/las-vacas-gordas-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 15,
#   'categories': [{'alias': 'steak', 'title': 'Steakhouses'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': -33.4411554711322,
#    'longitude': -70.663706055986},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': 'Cienfuegos 280',
#    'address2': None,
#    'address3': None,
#    'city': 'Santiago',
#    'zip_code': '8320000',
#    'country': 'CL',
#    'state': 'RM',
#    'display_address': ['Cienfuegos 280', 'RM 8320000 Santiago', 'Chile']},
#   'phone': '+56226971066',
#   'display_phone': '+56 2 2697 1066',
#   'distance': 3545.0610447809},
#  {'id': '8XAW5okaLleJD3FYTZnscw',
#   'alias': 'ramen-kintaro-santiago',
#   'name': 'Ramen Kintaro',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/yvW-Gd_o2yWZsCG1EcY-ZA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/ramen-kintaro-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 8,
#   'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': -33.4366925238364,
#    'longitude': -70.6440740078688},
#   'transactions': [],
#   'location': {'address1': 'Monjitas 460',
#    'address2': '',
#    'address3': None,
#    'city': 'Santiago',
#    'zip_code': '',
#    'country': 'CL',
#    'state': 'RM',
#    'display_address': ['Monjitas 460', 'RM Santiago', 'Chile']},
#   'phone': '+56226382448',
#   'display_phone': '+56 2 2638 2448',
#   'distance': 1891.4518059278432},
#  {'id': 'p5jngo0JYcNguv7upJwPwQ',
#   'alias': 'boragó-santiago',
#   'name': 'Boragó',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/OYDT4xQl3CewasEartvniA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/borag%C3%B3-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 25,
#   'categories': [{'alias': 'chilean', 'title': 'Chilean'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': -33.3824440981482,
#    'longitude': -70.5839843853195},
#   'transactions': [],
#   'location': {'address1': 'Av San Josemaría Escrivá de Balaguer 5970',
#    'address2': '',
#    'address3': None,
#    'city': 'Santiago',
#    'zip_code': '',
#    'country': 'CL',
#    'state': 'RM',
#    'display_address': ['Av San Josemaría Escrivá de Balaguer 5970',
#     'RM Santiago',
#     'Chile']},
#   'phone': '+56229538893',
#   'display_phone': '+56 2 2953 8893',
#   'distance': 7858.441378913182},
#  {'id': 'T6ENSUv8tDALgdBPdsTPWw',
#   'alias': 'miraolas-santiago-2',
#   'name': 'Miraolas',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/eoh6zLdN706psGJdnUMJ1A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/miraolas-santiago-2?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 13,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': -33.39974101, 'longitude': -70.59008077},
#   'transactions': [],
#   'price': '$$$',
#   'location': {'address1': 'Av. Vitacura 4171',
#    'address2': None,
#    'address3': None,
#    'city': 'Santiago',
#    'zip_code': '7630000',
#    'country': 'CL',
#    'state': 'RM',
#    'display_address': ['Av. Vitacura 4171', 'RM 7630000 Santiago', 'Chile']},
#   'phone': '+56222060202',
#   'display_phone': '+56 2 2206 0202',
#   'distance': 5922.884061292359},
#  {'id': 'iwDQhmGylgrDbp8gXeMtJw',
#   'alias': 'da-dino-santiago-2',
#   'name': 'Da-Dino',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/PhyuOjZwQXEZpDn6dhBBow/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/da-dino-santiago-2?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 5,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': -33.44195442, 'longitude': -70.6462221},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': "Av. Libertador Bernardo O'Higgins 737",
#    'address2': None,
#    'address3': None,
#    'city': 'Santiago',
#    'zip_code': '8320000',
#    'country': 'CL',
#    'state': 'RM',
#    'display_address': ["Av. Libertador Bernardo O'Higgins 737",
#     'RM 8320000 Santiago',
#     'Chile']},
#   'phone': '+5626381833',
#   'display_phone': '+56 26381833',
#   'distance': 1922.0625269183597},
#  {'id': 'FcQ0WD5LiJTxCZ0kGH2yww',
#   'alias': 'silvestre-bistró-santiago',
#   'name': 'Silvestre Bistró',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/n30v34WxuSs6vAIvwzD37Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/silvestre-bistr%C3%B3-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 14,
#   'categories': [{'alias': 'signature_cuisine', 'title': 'Signature Cuisine'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': -33.448243, 'longitude': -70.6236202},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': 'Caupolicán 511',
#    'address2': '',
#    'address3': '',
#    'city': 'Santiago',
#    'zip_code': '',
#    'country': 'CL',
#    'state': 'RM',
#    'display_address': ['Caupolicán 511', 'RM Santiago', 'Chile']},
#   'phone': '+56991569974',
#   'display_phone': '+56 9 9156 9974',
#   'distance': 511.2466070857914},
#  {'id': 'E57pMqeAUdogI1Y8D9alcw',
#   'alias': 'restaurant-vegetariano-soju-santiago',
#   'name': 'Restaurant Vegetariano Soju',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/eLkjk8eIGCXUX1z4KkWASA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/restaurant-vegetariano-soju-santiago?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 13,
#   'categories': [{'alias': 'vegan', 'title': 'Vegan'},
#    {'alias': 'vegetarian', 'title': 'Vegetarian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': -33.4380810113056,
#    'longitude': -70.648650560852},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': 'Galería Santiago',
#    'address2': 'Merced 821',
#    'address3': 'Local 17',
#    'city': 'Santiago',
#    'zip_code': '8320000',
#    'country': 'CL',
#    'state': 'RM',
#    'display_address': ['Galería Santiago',
#     'Merced 821',
#     'Local 17',
#     'RM 8320000 Santiago',
#     'Chile']},
#   'phone': '+56226895764',
#   'display_phone': '+56 2 2689 5764',
#   'distance': 2232.473144878206},
#  {'id': 'ru9I6hxoA3HqkkZpZ0p5UQ',
#   'alias': 'new-horizon-santiago-2',
#   'name': 'New Horizon',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/6MNsiI9_3FQHORctlleodA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/new-horizon-santiago-2?adjust_creative=GWOCZh9-BmZxtdsAjr7Gug&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=GWOCZh9-BmZxtdsAjr7Gug',
#   'review_count': 28,
#   'categories': [{'alias': 'indpak', 'title': 'Indian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': -33.437766, 'longitude': -70.64511},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': 'Merced 565',
#    'address2': '',
#    'address3': '',
#    'city': 'Santiago',
#    'zip_code': '8320000',
#    'country': 'CL',
#    'state': 'RM',
#    'display_address': ['Merced 565', 'RM 8320000 Santiago', 'Chile']},
#   'phone': '+56226323622',
#   'display_phone': '+56 2 2632 3622',
#   'distance': 1933.0318733238532}]

# %% [markdown]
# La data entregada por la API Yelp API es un objeto en formato JSON anidado, es decir, un diccionario donde algunos de los valores de atributos corresponden a su vez a listas o diccionarios.
#
# Como vimos anteriormente, podemos llevar estos datos a un formato "aplanado" o "flattened",utilizando la función `json_normalize()` :
#
# https://pandas.pydata.org/docs/reference/api/pandas.json_normalize.html

# %%
#normalizamos el contenido del diccionario "businesses"
rests = pd.json_normalize(data["businesses"],sep='_',record_path=['categories'],meta=['name','price','rating','review_count','distance',['coordinates','latitude'],['coordinates','longitude'],['location','address1']],errors='ignore') 
                                            # el parámetro 'errors' permite ignorar errores que puedan surgir al normalizar el json 
                                            # el parámetro 'record_path' permite indicar la ruta que se debe seguir para llegar a los datos que se quieren normalizar 
                                            # el parámetro 'meta' permite indicar los datos que se quieren mantener en el DataFrame
                                            # el parámetro 'sep' permite indicar el separador que se usará para los nombres de las columnas, en caso de que se normalicen datos anidados.
rests.head()
# Out:
#           alias           title                 name price rating  \
# 0     wine_bars       Wine Bars           Barrica 94    $$    4.5
# 1       chilean         Chilean           Barrica 94    $$    4.5
# 2  cocktailbars   Cocktail Bars           Barrica 94    $$    4.5
# 3       seafood         Seafood       Aquí Está Coco  $$$$    4.5
# 4         latin  Latin American  Restaurant Peumayén  $$$$    4.5
#
#   review_count     distance coordinates_latitude coordinates_longitude  \
# 0           77  1395.735019           -33.434288            -70.635224
# 1           77  1395.735019           -33.434288            -70.635224
# 2           77  1395.735019           -33.434288            -70.635224
# 3           57  2366.370671           -33.424063            -70.616624
# 4           71   1504.86354           -33.432807            -70.634821
#
#    location_address1
# 0     Bellavista 052
# 1     Bellavista 052
# 2     Bellavista 052
# 3  La Concepción 236
# 4   Constitución 136

# %% [markdown]
# La API cuenta con información relativa a 2300 restaurantes, pero en cada consulta se extrae una página con 50 resultados. Por lo tanto, para extraer todos los datos, será necesario iterar el proceso. El parámetro `offset` de la API indica el número de registros a avanzar en cada consulta (avanzamos de 50 en 50).

# %%
#iteramos
offset=0 # parámetro que permite avanzar en los resultados de la API (la API entrega los resultados de 50 en 50) 

#creamos una lista para reunir los dataframes creados para cada una de las consultas
allrests=[] 

#iteramos hasta llegar a 1000 resultados (el máximo que permite la API)
while offset<=950: 

    #parámetros de la consulta a la API
    params={'term':'restaurants','location':'RM Santiago, Chile','limit':50,'offset':offset} # el parámetro 'offset' permite avanzar en los resultados de la API (la API entrega los resultados de 50 en 50) 

    response=requests.get(api_url,params=params,headers=headers) #realizamos la consulta a la API con los parámetros definidos anteriormente 
    data=response.json() #obtenemos los datos en formato json 

    #dataframe con 50 resultados
    rests = pd.json_normalize(data["businesses"],sep='_',record_path=['categories'],meta=['name','price','rating','review_count','distance',['coordinates','latitude'],['coordinates','longitude'],['location','address1']],errors='ignore') 

    #agregamos este resultado a la lista de dataframes
    allrests.append(rests)

    #avanzamos 50 registros
    offset=offset+50

# %%
#Finalmente concatenamos todos los dataframes para crear uno solo con todos los resultados
rests=pd.concat(allrests,ignore_index=True) #ignore_index=True permite reindexar el dataframe resultante 
rests
# Out:
#               alias           title                 name price rating  \
# 0         wine_bars       Wine Bars           Barrica 94    $$    4.5
# 1           chilean         Chilean           Barrica 94    $$    4.5
# 2      cocktailbars   Cocktail Bars           Barrica 94    $$    4.5
# 3           seafood         Seafood       Aquí Está Coco  $$$$    4.5
# 4             latin  Latin American  Restaurant Peumayén  $$$$    4.5
# ...             ...             ...                  ...   ...    ...
# 1453        burgers         Burgers       Johnny Rockets     $    4.0
# 1454          salad           Salad                Tocha     $    5.0
# 1455            tea       Tea Rooms                Tocha     $    5.0
# 1456  mediterranean   Mediterranean             Avvocato    $$    3.0
# 1457        italian         Italian             Avvocato    $$    3.0
#
#      review_count      distance coordinates_latitude coordinates_longitude  \
# 0              77   1395.735019           -33.434288            -70.635224
# 1              77   1395.735019           -33.434288            -70.635224
# 2              77   1395.735019           -33.434288            -70.635224
# 3              57   2366.370671           -33.424063            -70.616624
# 4              71    1504.86354           -33.432807            -70.634821
# ...           ...           ...                  ...                   ...
# 1453            9  11274.318618            -33.43457             -70.74663
# 1454            1   2290.449323             -33.4268             -70.61193
# 1455            1   2290.449323             -33.4268             -70.61193
# 1456            5   2827.690815           -33.440096            -70.655768
# 1457            5   2827.690815           -33.440096            -70.655768
#
#                                    location_address1
# 0                                     Bellavista 052
# 1                                     Bellavista 052
# 2                                     Bellavista 052
# 3                                  La Concepción 236
# 4                                   Constitución 136
# ...                                              ...
# 1453  Aeropuerto Internacional Arturo Medina Benitez
# 1454                   Alfredo Barros Errázuriz 1978
# 1455                   Alfredo Barros Errázuriz 1978
# 1456                                  Huerfanos 1343
# 1457                                  Huerfanos 1343
#
# [1458 rows x 10 columns]

# %%
#exportar a csv
rests.to_csv('restaurants.csv',index=False)
